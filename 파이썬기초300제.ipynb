# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리 질렀다. "도둑이야".')
# Out:
# 신씨가 소리 질렀다. "도둑이야".

# %%
print("c:\\Windows")
# Out:
# c:\Windows

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")   #\n은 줄바꿈, \t은 tab(4칸) 띄우기이므로, \t\t은 8칸 띄우기
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
print('naver','kakao','sk','samsung', sep=";")
# Out:
# naver;kakao;sk;samsung

# %%
print('naver','kakao','sk','samsung', sep="/")
# Out:
# naver/kakao/sk/samsung

# %%
print("first", end=" ");print("second")
# Out:
# first second

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %%
x, y = input("두 수를 입력하세요: ").split()
x = int(x)
y = int(y)
print("두 수의 합:", x + y)
# Out:
# 두 수를 입력하세요:  3 5
# 두 수의 합: 8

# %%
print("로딩 중", end="...")
print("완료")
# Out:
# 로딩 중...완료
