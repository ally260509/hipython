# %%
#변수 price와 is_discount가 주어졌을 때, is_discount가 True이면 가격에 10% 할인을 적용하고,
#그렇지 않으면 원래 가격을 출력하는 코드를 작성하세요.

price = 500
is_discount = False

if is_discount == True :
    print(price * 0.9)
else:
    print(price)
# Out:
# 500

# %%
price = 1000
is_discount = True
final_price = 0

if is_discount :
    final_price = price * (1-0.1)
else :
    final_price = price   

print(final_price)
# Out:
# 900.0

# %%
#휴대폰 번호 앞자리에 따라 통신사는 아래와 같이 구분된다. 사용자로부터 휴대전화 번호를 입력 받고, 통신사를 출력하는 프로그램을 작성하라.
#번호 통신사 011 SKT 016 KT 019 LGU 010 알수없음
#휴대전화 번호 입력: 011-345-1922 당신은 SKT 사용자입니다.

num = input('휴대폰 번호를 입력해주세요: ').split('-')
tel = num[0]

if tel == '011' :
    print('당신은 SKT 사용자입니다')
elif tel == '016':
    print('당신은 KT 사용자입니다')
elif tel == '019':
    print('당신은 LGU 사용자입니다')
elif tel == '010':
    print('통신사를 알수 없습니다')
else:
    print('번호를 다시 입력해주세요')
# Out:
# 휴대폰 번호를 입력해주세요:  011-234-5566
# 당신은 SKT 사용자입니다

# %%
telecom = {'011':'SKT', '016':'KT', '019':'LGU', '010':'알수없음'}

num = input('휴대전화 번호를 입력해주세요: ').split('-')[0]

msg = telecom.get(num, '번호확인필요')
print(f'당신은 {msg}통신사의 사용자입니다.')

#get은 꺼내려고 하는 값을 key로 넣어야 함
# Out:
# 휴대전화 번호를 입력해주세요:  011-234-5566
# 당신은 SKT통신사의 사용자입니다.

# %%
#아래 코드는 비트코인의 가격 정보를 딕셔너리로 가져오는 코드이다. 
#import requests btc = requests.get("https://api.bithumb.com/public/ticker/").json()['data'] 
#btc 딕셔너리 안에는 시가, 종가, 최고가, 최저가 등이 저장되어 있다. 
#최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장",
#그렇지 않은 경우 "하락장" 문자열을 출력하라.
#Key Name Description opening_price 최근 24시간 내 시작 거래금액 
#closing_price 최근 24시간 내 마지막 거래금액 
#min_price 최근 24시간 내 최저 거래금액 
#max_price 최근 24시간 내 최고 거래금액

import requests
btc = requests.get("https://api.bithumb.com/public/ticker/").json()['data']

변동폭 = int(btc['max_price']) - int(btc['min_price'])
시가 = int(btc['opening_price'])
최고가 = int(btc['max_price'])

if 시가 + 변동폭 > 최고가:
    print('상승장')
else:
    print('하락장')
# Out:
# 상승장

# %%
import requests
btc = requests.get("https://api.bithumb.com/public/ticker/").json()['data']

시가 = int(btc['opening_price'])
최고가 = int(btc['max_price'])
변동폭 = 최고가 - int(btc['min_price'])

if  시가+변동폭 > 최고가 :
    print('상승장')
else :
    print('하락장')
# Out:
# 상승장

# %%
#구구단을 출력하세요
#1. 짝수단, 홀수단 구분
#2. 2~4단 첫줄, 5~9단 둘째줄에 출력

# %%
for i in range(2,10):
    for j in range(1,10):
        print(f'{i} * {j} = {i*j}')
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81

# %%
for i in range(2,10,2):
    for j in range(1,10):
        print(f'{i} * {j} = {i*j}')
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72

# %%
for i in range(3,10,2):
    for j in range(1,10):
        print(f'{i} * {j} = {i * j}')
# Out:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81

# %%
#2~5단 (첫줄)
print("\n[2~5단]")
for j in range(1,10):  # 10줄 반복
    line = ''
    for i in range(2,6): # 2~4단
        line += f'{i} * {j} = {i * j:2d}   '  #3칸 공백으로 연결
    print(line)   

#6~9단 (다음줄)
print("\n[6~9단]")
for j in range(1,10):  # 10줄 반복
    line = ''
    for i in range(6,10): # 2~4단
        line += f'{i} * {j} = {i * j:2d}   '  #3칸 공백으로 연결
    print(line)
# Out:
# [2~5단]
# 2 * 1 =  2   3 * 1 =  3   4 * 1 =  4   5 * 1 =  5
# 2 * 2 =  4   3 * 2 =  6   4 * 2 =  8   5 * 2 = 10
# 2 * 3 =  6   3 * 3 =  9   4 * 3 = 12   5 * 3 = 15
# 2 * 4 =  8   3 * 4 = 12   4 * 4 = 16   5 * 4 = 20
# 2 * 5 = 10   3 * 5 = 15   4 * 5 = 20   5 * 5 = 25
# 2 * 6 = 12   3 * 6 = 18   4 * 6 = 24   5 * 6 = 30
# 2 * 7 = 14   3 * 7 = 21   4 * 7 = 28   5 * 7 = 35
# 2 * 8 = 16   3 * 8 = 24   4 * 8 = 32   5 * 8 = 40
# 2 * 9 = 18   3 * 9 = 27   4 * 9 = 36   5 * 9 = 45
#
# [6~9단]
# 6 * 1 =  6   7 * 1 =  7   8 * 1 =  8   9 * 1 =  9
# 6 * 2 = 12   7 * 2 = 14   8 * 2 = 16   9 * 2 = 18
# 6 * 3 = 18   7 * 3 = 21   8 * 3 = 24   9 * 3 = 27
# 6 * 4 = 24   7 * 4 = 28   8 * 4 = 32   9 * 4 = 36
# 6 * 5 = 30   7 * 5 = 35   8 * 5 = 40   9 * 5 = 45
# 6 * 6 = 36   7 * 6 = 42   8 * 6 = 48   9 * 6 = 54
# 6 * 7 = 42   7 * 7 = 49   8 * 7 = 56   9 * 7 = 63
# 6 * 8 = 48   7 * 8 = 56   8 * 8 = 64   9 * 8 = 72
# 6 * 9 = 54   7 * 9 = 63   8 * 9 = 72   9 * 9 = 81

# %%
#양수음수분류기

while True:
    #입력 받기 & 정수 목록 만들기
    user_input = input('정수의 목록을 공백으로 구분해서 입력하세요. 종료: "q"')
    #종료 명령이면 break
    if user_input == 'q' :
        break
    str_int = user_input.split()
    numbers = []  #초기값

    #int(user_input)
    for num in str_int:
        # if num == '0' :
        #     continue
        if num != '0':
            numbers.append(int(num))
    # 입력받은 정수 리스트
    print(numbers)
    #입력한 숫자가 없습니다. 체크
    if numbers == None :
        print('입력받은 숫자가 없습니다')
    #양수/음수 판단 > 카운트
    plus_numbers = []
    minus_numbers = []
    for num in numbers :
        if num > 0 :
            plus_numbers.append(num)
        else: num < 0 :
            minus_numbers.append(num)
    plus_numbers, minus_numbers
    
    

    #합계 계산
    #출력
    print(f'양수: {}개, 음수: {}개, 합계: {}점')

        
    
    if nums < 0 :
        print('음수입니다')
    elif nums > 0 :
        print('양수입니다')
    else:
        print()
# Out:
#   Cell In[12], line 29
#     else: num < 0 :
#                   ^
# SyntaxError: invalid syntax

# %%
# 초대장 생성 프로그램

from datetime import datetime

vip_list = input('vip 이름을 입력해주세요: ')
coupon_no = input('쿠폰 번호를 입력해주세요: ')
year = datetime.now().year

print(f'''
{vip_list}님 안녕하세요?
화창한 {year}년 가을, 저희 컴퓨터 동아리 축제에 {vip_list}님을 초대합니다.
쿠폰 No. {coupon_no}
{vip_list}님 축제에서 만나길 고대하겠습니다.
''')

# %%
user_input = input('정수의 목록을 공백으로 구분해서 입력하세요. 종료: "q"')
str_int = user_input.split()
numbers = []
    
for num in str_int:
    if num == '0' :
        continue
    numbers.append(int(num))
    print(numbers)

# %%
while True:
    #입력 받기 & 정수 목록 만들기
    user_input = input('정수의 목록을 공백으로 구분해서 입력하세요. 종료: "q"')
    #종료 명령이면 break
    if user_input == 'q' :
        break
    str_int = user_input.split()
    numbers = []  #초기값

    #int(user_input)
    for num in str_int:
        # if num == '0' :
        #     continue
        if num != '0':
            numbers.append(int(num))
    # 입력받은 정수 리스트
    print(numbers)
    #입력한 숫자가 없습니다. 체크
    if numbers == None :
        print('입력받은 숫자가 없습니다')
    #양수/음수 판단 > 카운트
    plus_numbers = []
    minus_numbers = []
    for num in numbers :
        if num > 0 :
            plus_numbers.append(num)
        else: 
            minus_numbers.append(num)
    #print(plus_numbers, minus_numbers)
    pls_cnt = len(plus_numbers)
    minus_cnt = len(minus_numbers)
    total = sum(numbers)
    print(f'양수:{pls_cnt}개 음수:{minus_cnt}개  총합계:{total}')
    print()
# Out:
# 정수의 목록을 공백으로 구분해서 입력하세요. 종료: "q" 0 30 42 -20 50 -100
# [30, 42, -20, 50, -100]
# 양수:3개 음수:2개  총합계:2
# 정수의 목록을 공백으로 구분해서 입력하세요. 종료: "q" q
