# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001/'
bestseller = requests.get(url)
bestseller.text[:500]  #HTML의 처음 500글자 출력
# Out:
# '\r\n\r\n\r\n\r\n\r\n    \r\n\t<!DOCTYPE html >\r\n\t<html lang="ko">\r\n\r\n<head><link rel="alternate" media="only screen and(max-width: 640px)" href="https://m.yes24.com/Home/Best?DispNo=001">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n\t<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />\r\n\t<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />\r\n\t<meta http-equiv="Accept-CH-Lifetime" c'

# %%
selector = "#yesBestList div.item_info"
soup = BeautifulSoup(bestseller.text, 'html.parser')
items = soup.select(selector)
len(items)  #베스트셀러 상품의 수
items[0]    #첫번째 상품의 HTML 코드
# Out:
# <div class="item_info">
# <div class="info_row info_keynote">
# <span class="gd_keynote" id="spanGdKeynote">
# <!-- 클래스24 상품일 경우 -->
# </span>
# <script type="text/javascript">
#         if ($('#spanGdKeynote').children().length == 0) {
#             $('#spanGdKeynote').remove();
#         }
#     </script>
# </div>
# <div class="info_row info_name">
# <span class="gd_res">[도서]</span>
# <a class="gd_name" href="/product/goods/173082175" onclick="wiseLogV2('BS', '001_005_001', ''); ">나의 완벽한 장례식</a>
# <a class="bgYUI ico_nWin" href="/product/goods/173082175" onclick="wiseLogV2('BS', '001_005_001', ''); " target="_blank">나의 완벽한 장례식 새창이동</a>
# </div>
# <div class="info_row info_pubGrp">
# <span class="authPub info_auth" onclick="wiseLogV2('BS', '001_005_002', '');">
# <a href="https://www.yes24.com/product/search?domain=ALL&amp;query=%25EC%25A1%25B0%25ED%2598%2584%25EC%2584%25A0&amp;authorNo=484250&amp;author=조현선" target="">조현선</a> 저
#                             </span>
# <span class="authPub info_pub" onclick="wiseLogV2('BS', '001_005_003', '');"><a href="https://www.yes24.com/product/search?&amp;domain=ALL&amp;company=%eb%b6%81%eb%a1%9c%eb%a7%9d%ec%8a%a4&amp;query=%25EB%25B6%2581%25EB%25A1%259C%25EB%25A7%259D%25EC%258A%25A4">북로망스</a></span>
# <span class="authPub info_date">2026년 01월</span>
# </div>
# <div class="info_row info_price">
# <span class="txt_sale"><em class="num">10</em>%</span>
# <strong class="txt_num"><em class="yes_b">17,100</em>원</strong>
# <span class="txt_num dash"><em class="yes_m">19,000</em>원</span>
# <span class="yPoint"><em class="bgYUI ico_point">포인트적립</em>950원</span>
# </div>
# <div class="info_row info_rating">
# <span class="saleNum">
#                                 판매지수 147,336
#                             </span>
# <span class="rating_rvCount">
# <a href="https://www.yes24.com/product/goods/173082175?ReviewYn=Y" onclick="wiseLogV2('BS', '001_005_004', '');"><em class="bit">회원리뷰</em>(<em class="txC_blue">61</em>건)</a>
# </span>
# <span class="rating_grade">
# <span class="bgYUI tRating tRating_10">리뷰 총점</span><em class="yes_b">9.7</em>
# <span class="moreRatingArea">
# <span class="moreRatingBtn">
# <a class="bgYUI" href="javascript:void(0);" onclick="toggleLiCont(this,$('.sGLi'),event);">정보 더 보기/감추기</a>
# </span>
# <span class="moreRatingLi">
# <span class="moreRatingLiRow">
# <ul class="yesAlertLi">
# <li><em class="bl_dot bgYUI"> </em>종이책 리뷰 (53건)</li>
# <li><em class="bl_dot bgYUI"> </em>eBook 리뷰 (0건)</li>
# <li><em class="bl_dot bgYUI"> </em>종이책 한줄평 (8건)</li>
# <li><em class="bl_dot bgYUI"> </em>eBook 한줄평 (0건)</li>
# </ul>
# </span>
# </span>
# </span>
# </span>
# </div>
# <div class="info_row info_deli" name="delvTextArea"></div>
# <div class="info_row info_tag">
# <span class="tag">
# <a href="https://www.yes24.com/product/search?domain=ALL&amp;query=%25EC%25B6%259C%25ED%2587%25B4%25EA%25B7%25BC%25EA%25B8%25B8%25EC%2599%2584%25EB%258F%2585%25EB%258F%2584%25EC%25A0%2584&amp;hashNm=%ec%b6%9c%ed%87%b4%ea%b7%bc%ea%b8%b8%ec%99%84%eb%8f%85%eb%8f%84%ec%a0%84" onclick="wiseLogV2('BS', '001_005_005', ''); setTagClickExtraCode('100', '출퇴근길완독도전', '173082175','9060');">#출퇴근길완독도전</a>
# </span>
# </div>
# <div class="info_row info_relG">
#                     관련상품 :                            <span class="relG"><a href="/product/goods/180226575">eBook <span class="relG_num">13,680원</span></a></span>
# </div>
# </div>

# %%
# 책제목
#yesBestList > li:nth-child(1) > div > div.item_info > div.info_row.info_name > a.gd_name

title_selector = "div.info_name > a.gd_name"
items[0].select_one(title_selector).text
# Out:
# '나의 완벽한 장례식'

# %%
# 저자명
#yesBestList > li:nth-child(1) > div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_pub

author_selector = "span.authPub.info_auth > a"
items[0].select_one(author_selector).text
# Out:
# '조현선'

# %%
# 가격
#yesBestList > li:nth-child(1) > div > div.item_info > div.info_row.info_price > strong > em

price_selector = "div.info_row.info_price > strong"
items[0].select_one(price_selector).text
# Out:
# '17,100원'

# %%
# 베스트셀러 상품목록의 제목, 저자명, 가격을 출력

for i, item in enumerate(items):
    title = item.select_one(title_selector).text.strip()
    author = item.select_one(author_selector).text.strip()
    price = item.select_one(price_selector).text.strip()
    print(f"{i+1}. {title} / {author} / {price}")
# Out:
# 1. 나의 완벽한 장례식 / 조현선 / 17,100원
# 2. 진보를 위한 주식투자 / 이광수 / 19,800원
# 3. 박곰희 연금 부자 수업 / 박곰희 / 18,900원
# 4. 괴테는 모든 것을 말했다 / 스즈키 유이 / 15,300원
# 5. ETS 토익 정기시험 기출문제집 1000 Vol. 5 RC / ETS / 19,800원
# 6. ETS 토익 정기시험 기출문제집 1000 Vol. 5 LC / ETS / 19,800원
# 7. 죽은 왕녀를 위한 파반느 (양장 특별판) / 박민규 / 18,000원
# 8. 자몽살구클럽 / 한로로 / 10,800원
# 9. 2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상 / 최태성 / 17,100원
# 10. 너를 아끼며 살아라 / 나태주 / 16,650원
# 11. 모순 / 양귀자 / 11,700원
# 12. 돈의 방정식 / 모건 하우절 / 25,200원
# 13. 자본주의 시대에서 살아남기 위한 최소한의 경제 공부 / 백억남(김욱현) / 25,200원
# 14. 1,000만 원으로 3년 안에 300만 원 월배당 만들기 / 인생업(임승현) / 20,700원
# 15. 위버멘쉬 / 프리드리히 니체 / 16,020원
# 16. 엄마가 유령이 되었어! / 노부미 / 10,800원
# 17. 안녕이라 그랬어 / 김애란 / 15,120원
# 18. 2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하 / 최태성 / 16,650원
# 19. 최소한의 삼국지 / 최태성 / 17,550원
# 20. 싯다르타 / 헤르만 헤세 / 7,200원
# 21. 2026 심우철 실전 동형 모의고사 Season 2 / 심우철 / 13,500원
# 22. 사이토 히토리의 어떻게 살 것인가 / 사이토 히토리 / 11,700원
# 23. 돈의 심리학 (50만 부 기념 뉴 에디션) / 모건 하우절 / 22,320원
# 24. 더블 클릭 / 알간지 / 17,100원

# %%
class Book:
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self.price = price

    def __str__(self):
        return f"{self.title} / {self.author} / {self.price}"

# %%
# 페이지 지정
base_url = 'https://www.yes24.com/Product/Category/BestSeller?CategoryNumber=001&sumgb=06&PageNumber='
books = []
for page in range(1,7):
  url = f'{base_url}{page}'
  
  bestseller = requests.get(url)
  soup = BeautifulSoup(bestseller.text, 'html.parser')
  items = soup.select(selector)

  for i, item in enumerate(items):
      title = item.select_one(title_selector).text.strip()
      author = item.select_one(author_selector).text.strip()
      price = item.select_one(price_selector).text.strip()
      book = Book(title, author, price) # Book 객체 생성
      books.append(book) # Book 객체를 리스트에 추가
      
      print(f"{(page-1)*24 + i+1}. {book}")
# Out:
# 1. 나의 완벽한 장례식 / 조현선 / 17,100원
# 2. 진보를 위한 주식투자 / 이광수 / 19,800원
# 3. 박곰희 연금 부자 수업 / 박곰희 / 18,900원
# 4. 괴테는 모든 것을 말했다 / 스즈키 유이 / 15,300원
# 5. ETS 토익 정기시험 기출문제집 1000 Vol. 5 RC / ETS / 19,800원
# 6. ETS 토익 정기시험 기출문제집 1000 Vol. 5 LC / ETS / 19,800원
# 7. 죽은 왕녀를 위한 파반느 (양장 특별판) / 박민규 / 18,000원
# 8. 자몽살구클럽 / 한로로 / 10,800원
# 9. 2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상 / 최태성 / 17,100원
# 10. 너를 아끼며 살아라 / 나태주 / 16,650원
# 11. 모순 / 양귀자 / 11,700원
# 12. 돈의 방정식 / 모건 하우절 / 25,200원
# 13. 자본주의 시대에서 살아남기 위한 최소한의 경제 공부 / 백억남(김욱현) / 25,200원
# 14. 1,000만 원으로 3년 안에 300만 원 월배당 만들기 / 인생업(임승현) / 20,700원
# 15. 위버멘쉬 / 프리드리히 니체 / 16,020원
# 16. 엄마가 유령이 되었어! / 노부미 / 10,800원
# 17. 안녕이라 그랬어 / 김애란 / 15,120원
# 18. 2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하 / 최태성 / 16,650원
# 19. 최소한의 삼국지 / 최태성 / 17,550원
# 20. 싯다르타 / 헤르만 헤세 / 7,200원
# 21. 2026 심우철 실전 동형 모의고사 Season 2 / 심우철 / 13,500원
# 22. 사이토 히토리의 어떻게 살 것인가 / 사이토 히토리 / 11,700원
# 23. 돈의 심리학 (50만 부 기념 뉴 에디션) / 모건 하우절 / 22,320원
# 24. 더블 클릭 / 알간지 / 17,100원
# 25. 사카모토 데이즈 25 더블특전판 / 스즈키 유우토 / 5,850원
# 26. 부처님 말씀대로 살아보니 / 토니 페르난도 / 17,010원
# 27. 캔들차트 하나로 끝내는 추세추종 투자 / 성승현 / 22,500원
# 28. 코스피 1만 넥스트 레벨 / 박시동 / 19,800원
# 29. 혼모노 / 성해나 / 16,200원
# 30. 해커스 토익 기출 VOCA (보카) / David Cho / 11,610원
# 31. 나의 첫 월배당 ETF / 김정란 / 19,800원
# 32. 이해찬 회고록 / 이해찬 / 20,700원
# 33. 설민석의 한국사 대모험 36 / 설민석 / 14,400원
# 34. 코스모스 / 칼 에드워드 세이건 / 19,800원
# 35. 향기로운 꽃은 늠름하게 핀다 18 더블특전판 / 미카미 사카 / 5,400원
# 36. 운명을 보는 기술 / 박성준 / 16,920원
# 37. 교사를 지키는 단단한 학급경영 / 이종혁 / 16,200원
# 38. 어른의 행복은 조용하다 / 태수 / 16,020원
# 39. 2026 써니 행정법총론 실전동형 모의고사 / 박준철 / 14,400원
# 40. 2026 큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화(1,2,3급) / 최태성 / 19,800원
# 41. 주식투자 무작정 따라하기 / 윤재수 / 22,500원
# 42. 절창 切創 / 구병모 / 16,200원
# 43. 아주 작은 습관의 힘 (50만 부 기념 스페셜 에디션) / 제임스 클리어 / 16,200원
# 44. 2026 문동균 한국사 국가직 대비 실전 봉투 모의고사 / 문동균 / 11,700원
# 45. 2026 심우철 실전 동형 모의고사 Season 1 / 심우철 / 13,500원
# 46. 내가 돈을 벌고 있다는 착각 / commonD / 17,820원
# 47. 최소한의 한국사 / 최태성 / 16,200원
# 48. 내 심장을 쏴라 / 정유정 / 16,200원
# 49. 2026 선재국어 결승선 봉투 모의고사 / 이선재 / 25,200원
# 50. 2026 문동균 한국사 문단속 적중 최종병기 FINAL 모의고사 / 문동균 / 14,400원
# 51. 내 친구는 왜 그럴까? / 최현주 / 15,120원
# 52. 급류 / 정대건 / 12,600원
# 53. 김재우의 기본 동사 100 / 김재우 / 19,800원
# 54. 다크 심리학 / 다크 사이드 프로젝트 / 19,710원
# 55. 해커스 일본어 첫걸음 : 일본어 기초 20일 독학 완성! / 해커스 일본어연구소 / 12,510원
# 56. SQL 자격검정 실전문제 / 한국데이터진흥원 / 17,460원
# 57. 렛뎀 이론 / 멜 로빈스 / 18,000원
# 58. 니체의 초월자 / 프리드리히 니체 / 15,210원
# 59. ETS 토익 단기공략 750+ (LC+RC) / ETS / 17,550원
# 60. 프로젝트 헤일메리 (영화 특별판) / 앤디 위어 / 19,800원
# 61. 여덟 단어 / 박웅현 / 15,300원
# 62. 데일 카네기 인간관계론 (50만부 돌파 초판 무삭제 완역본) / 데일 카네기 / 10,350원
# 63. 브람스를 좋아하세요... / 프랑수아즈 사강 / 9,000원
# 64. 긴긴밤 / 루리 / 11,250원
# 65. 블루 아카이브 공식 4컷 청춘? 일상! 블루 아카이브 특별판 / 돈미니 / 47,700원
# 66. 2026 문동균 한국사 D-30 문단속 모의고사 / 문동균 / 14,400원
# 67. 인생을 위한 최소한의 생각 / 신영준 / 17,820원
# 68. 오늘 밤, 세계에서 이 사랑이 사라진다 해도 / 이치조 미사키 / 12,600원
# 69. 이게 되네? 제미나이 완전 미친 활용법 81제 / 오힘찬 / 21,600원
# 70. 세이노의 가르침 / 세이노(SayNo) / 6,480원
# 71. 단다단 19 / 타츠 유키노부 / 5,400원
# 72. 우리는 언제나 다시 만나 / 윤여림 / 10,800원
# 73. 데미안 / 헤르만 헤세 / 7,200원
# 74. 체인소 맨 22 / 후지모토 타츠키 / 5,400원
# 75. 이기적 유전자 The Selfish Gene / 리처드 도킨스 / 18,000원
# 76. 2026 황철곤 행정학 실전동형 모의고사 SEASON 1 / 황철곤 / 14,400원
# 77. 떠난 것은 돌아오지 않는다 / 줄리언 반스 / 16,200원
# 78. 신뢰 게임 / 현순엽 / 22,000원
# 79. 너를 미워할 시간에 나를 사랑하기로 했다 / 윤서진 / 16,920원
# 80. 세종의 나라 1 / 김진명 / 19,800원
# 81. 나쁜 일이 있어도 나쁜 날은 아니야 / 정문정 / 15,120원
# 82. 부의 인문학 (20만부 기념 개정증보판) / 브라운스톤(우석) / 15,300원
# 83. 인간 실격 / 다자이 오사무 / 8,100원
# 84. 의사 어벤저스 25 / 고희정 / 14,220원
# 85. Again! 뒤집어본 영문법 / 오성호 / 13,410원
# 86. 할매 / 황석영 / 15,120원
# 87. 원피스 ONE PIECE 113 / 오다 에이이치로 / 5,850원
# 88. 돈의 속성 400쇄 리커버 / 김승호 / 16,020원
# 89. 쇼펜하우어 인생수업 (30만 부 기념 개정증보판) / 쇼펜하우어 / 15,750원
# 90. 소년이 온다 / 한강 / 13,500원
# 91. Go Go 카카오프렌즈 39 칠레 / 김미영 / 15,210원
# 92. 나는 소망한다 내게 금지된 것을 / 양귀자 / 13,500원
# 93. 2026 심승아 Simple·Detail 소방학개론 심봉사 심승아 봉투 모의고사 / 심승아 / 8,100원
# 94. ETF 투자의 모든 것 / 문일호 / 18,900원
# 95. 편안함의 습격 / 마이클 이스터 / 19,800원
# 96. 일본 광고 카피 도감 / 오하림 / 16,920원
# 97. 세종의 나라 2 / 김진명 / 19,800원
# 98. 최상위권의 생기부 / 정성민 / 40,500원
# 99. 어른의 품격을 채우는 100일 필사 노트 / 김종원 / 18,000원
# 100. 흔한남매 21 / 흔한남매 / 15,120원
# 101. 해커스 보카 Hackers Vocabulary / David Cho / 15,210원
# 102. 은애하는 도적님아 대본집 세트 / 이선 / 47,700원
# 103. 해커스 일본어 첫걸음 히라가나 가타카나 쓰기노트 / 해커스 일본어연구소 / 7,200원
# 104. 데일리 필로소피 / 라이언 홀리데이 / 16,200원
# 105. 쾌적한 사회의 불쾌함 / 구마시로 도루 / 18,900원
# 106. 2026 이유진 국어 백일기도 모의고사 [結(결) 적중] / 이유진 / 30,600원
# 107. 달러 자산 1억으로 평생 월급 완성하라 (2026 투자 전략 특별판) / 채부심(채상욱) / 18,900원
# 108. 행복할 거야 이래도 되나 싶을 정도로 / 일홍 / 16,200원
# 109. 기적의 초등 신문 2026 / 강버들 / 17,820원
# 110. 2026 선재국어 출발선 봉투 모의고사 / 이선재 / 25,200원
# 111. 부모는 가장 좋은 입시 멘토다 / 박성오 / 16,920원
# 112. 1984 / 조지 오웰 / 9,900원
# 113. 2026 유휘운 행정법총론 실전동형 모의고사 / 유휘운 / 9,900원
# 114. 절대수익 우량주 매매법 / 성경호 / 35,100원
# 115. 규칙파괴자 / 데이비드 가드너 / 22,500원
# 116. 하루 한 장 나의 어휘력을 위한 필사 노트 / 유선경 / 21,420원
# 117. 스킵과 로퍼 11 더블 특전판 / 타카마츠 미사키 / 5,400원
# 118. ETS 토익기출 파트별 VOCA 보카 / ETS / 11,700원
# 119. 어른의 그릇 / 조윤제 / 17,100원
# 120. 이방인 / 알베르 까뮈 / 9,000원
# 121. 2026 이유진 국어 백일기도 모의고사 [承(승)_시간단축] / 이유진 / 25,200원
# 122. 정답은 있다 / 이정효 / 16,200원
# 123. 뇌는 어떻게 나를 조종하는가 / 크리스 나이바우어 / 16,920원
# 124. 새들이 전하는 짧은 철학 / 필리프 J. 뒤부아 / 15,300원
# 125. 2026 이유진 국어 백일기도 모의고사 [轉(전) 극한훈련] / 이유진 / 25,200원
# 126. 눈과 돌멩이 / 위수정 / 16,200원
# 127. 어머니의 집밥을 먹을 수 있는 횟수는 328번 남았습니다 / 우와노 소라 / 15,120원
# 128. 반짝반짝 1학년, 학교는 널 기다려! / 전영신 / 13,050원
# 129. 손자병법 / 손자 / 11,700원
# 130. 김재우의 기초 영어회화 100 / 김재우 / 17,010원
# 131. 메이지의 영원한 삶을 위해 / 크리스토퍼 엣지 / 11,700원
# 132. 존리의 부자되기 습관 / 존리 / 18,000원
# 133. 해커스 토익 RC Reading(리딩) 기본서 / David Cho / 16,920원
# 134. 비실비실 선생님 11 / 후쿠치 카미오 / 5,400원
# 135. 초판본 데미안 / 헤르만 헤세 / 1,980원
# 136. AI 시대 십 대를 위한 논어 / 최태규 / 16,920원
# 137. 총 균 쇠 / 재레드 다이아몬드 / 26,820원
# 138. 두근두근 1학년, 우리는 널 사랑해! / 전영신 / 13,050원
# 139. 몬스터 캠핑장 / 정주영 / 12,600원
# 140. 말뚝들 / 김홍 / 15,120원
# 141. 어린이 같은 말 다른 뜻 사전 / 박세랑 / 16,020원
# 142. 2026 위포트 공기업 NCS 통합기본서 (PSAT형+모듈형+피듈형+실전 모의고사) / 위포트 연구소 / 24,300원
# 143. 기분이 태도가 되지 않게 (헬로키티 에디션) / 레몬심리 / 16,200원
# 144. 불변의 법칙 / 모건 하우절 / 22,500원

# %%
len(books)
# Out:
# 144

# %%
for book in books:
  print(book)
# Out:
# 나의 완벽한 장례식 / 조현선 / 17,100원
# 진보를 위한 주식투자 / 이광수 / 19,800원
# 박곰희 연금 부자 수업 / 박곰희 / 18,900원
# 괴테는 모든 것을 말했다 / 스즈키 유이 / 15,300원
# ETS 토익 정기시험 기출문제집 1000 Vol. 5 RC / ETS / 19,800원
# ETS 토익 정기시험 기출문제집 1000 Vol. 5 LC / ETS / 19,800원
# 죽은 왕녀를 위한 파반느 (양장 특별판) / 박민규 / 18,000원
# 자몽살구클럽 / 한로로 / 10,800원
# 2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상 / 최태성 / 17,100원
# 너를 아끼며 살아라 / 나태주 / 16,650원
# 모순 / 양귀자 / 11,700원
# 돈의 방정식 / 모건 하우절 / 25,200원
# 자본주의 시대에서 살아남기 위한 최소한의 경제 공부 / 백억남(김욱현) / 25,200원
# 1,000만 원으로 3년 안에 300만 원 월배당 만들기 / 인생업(임승현) / 20,700원
# 위버멘쉬 / 프리드리히 니체 / 16,020원
# 엄마가 유령이 되었어! / 노부미 / 10,800원
# 안녕이라 그랬어 / 김애란 / 15,120원
# 2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하 / 최태성 / 16,650원
# 최소한의 삼국지 / 최태성 / 17,550원
# 싯다르타 / 헤르만 헤세 / 7,200원
# 2026 심우철 실전 동형 모의고사 Season 2 / 심우철 / 13,500원
# 사이토 히토리의 어떻게 살 것인가 / 사이토 히토리 / 11,700원
# 돈의 심리학 (50만 부 기념 뉴 에디션) / 모건 하우절 / 22,320원
# 더블 클릭 / 알간지 / 17,100원
# 사카모토 데이즈 25 더블특전판 / 스즈키 유우토 / 5,850원
# 부처님 말씀대로 살아보니 / 토니 페르난도 / 17,010원
# 캔들차트 하나로 끝내는 추세추종 투자 / 성승현 / 22,500원
# 코스피 1만 넥스트 레벨 / 박시동 / 19,800원
# 혼모노 / 성해나 / 16,200원
# 해커스 토익 기출 VOCA (보카) / David Cho / 11,610원
# 나의 첫 월배당 ETF / 김정란 / 19,800원
# 이해찬 회고록 / 이해찬 / 20,700원
# 설민석의 한국사 대모험 36 / 설민석 / 14,400원
# 코스모스 / 칼 에드워드 세이건 / 19,800원
# 향기로운 꽃은 늠름하게 핀다 18 더블특전판 / 미카미 사카 / 5,400원
# 운명을 보는 기술 / 박성준 / 16,920원
# 교사를 지키는 단단한 학급경영 / 이종혁 / 16,200원
# 어른의 행복은 조용하다 / 태수 / 16,020원
# 2026 써니 행정법총론 실전동형 모의고사 / 박준철 / 14,400원
# 2026 큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화(1,2,3급) / 최태성 / 19,800원
# 주식투자 무작정 따라하기 / 윤재수 / 22,500원
# 절창 切創 / 구병모 / 16,200원
# 아주 작은 습관의 힘 (50만 부 기념 스페셜 에디션) / 제임스 클리어 / 16,200원
# 2026 문동균 한국사 국가직 대비 실전 봉투 모의고사 / 문동균 / 11,700원
# 2026 심우철 실전 동형 모의고사 Season 1 / 심우철 / 13,500원
# 내가 돈을 벌고 있다는 착각 / commonD / 17,820원
# 최소한의 한국사 / 최태성 / 16,200원
# 내 심장을 쏴라 / 정유정 / 16,200원
# 2026 선재국어 결승선 봉투 모의고사 / 이선재 / 25,200원
# 2026 문동균 한국사 문단속 적중 최종병기 FINAL 모의고사 / 문동균 / 14,400원
# 내 친구는 왜 그럴까? / 최현주 / 15,120원
# 급류 / 정대건 / 12,600원
# 김재우의 기본 동사 100 / 김재우 / 19,800원
# 다크 심리학 / 다크 사이드 프로젝트 / 19,710원
# 해커스 일본어 첫걸음 : 일본어 기초 20일 독학 완성! / 해커스 일본어연구소 / 12,510원
# SQL 자격검정 실전문제 / 한국데이터진흥원 / 17,460원
# 렛뎀 이론 / 멜 로빈스 / 18,000원
# 니체의 초월자 / 프리드리히 니체 / 15,210원
# ETS 토익 단기공략 750+ (LC+RC) / ETS / 17,550원
# 프로젝트 헤일메리 (영화 특별판) / 앤디 위어 / 19,800원
# 여덟 단어 / 박웅현 / 15,300원
# 데일 카네기 인간관계론 (50만부 돌파 초판 무삭제 완역본) / 데일 카네기 / 10,350원
# 브람스를 좋아하세요... / 프랑수아즈 사강 / 9,000원
# 긴긴밤 / 루리 / 11,250원
# 블루 아카이브 공식 4컷 청춘? 일상! 블루 아카이브 특별판 / 돈미니 / 47,700원
# 2026 문동균 한국사 D-30 문단속 모의고사 / 문동균 / 14,400원
# 인생을 위한 최소한의 생각 / 신영준 / 17,820원
# 오늘 밤, 세계에서 이 사랑이 사라진다 해도 / 이치조 미사키 / 12,600원
# 이게 되네? 제미나이 완전 미친 활용법 81제 / 오힘찬 / 21,600원
# 세이노의 가르침 / 세이노(SayNo) / 6,480원
# 단다단 19 / 타츠 유키노부 / 5,400원
# 우리는 언제나 다시 만나 / 윤여림 / 10,800원
# 데미안 / 헤르만 헤세 / 7,200원
# 체인소 맨 22 / 후지모토 타츠키 / 5,400원
# 이기적 유전자 The Selfish Gene / 리처드 도킨스 / 18,000원
# 2026 황철곤 행정학 실전동형 모의고사 SEASON 1 / 황철곤 / 14,400원
# 떠난 것은 돌아오지 않는다 / 줄리언 반스 / 16,200원
# 신뢰 게임 / 현순엽 / 22,000원
# 너를 미워할 시간에 나를 사랑하기로 했다 / 윤서진 / 16,920원
# 세종의 나라 1 / 김진명 / 19,800원
# 나쁜 일이 있어도 나쁜 날은 아니야 / 정문정 / 15,120원
# 부의 인문학 (20만부 기념 개정증보판) / 브라운스톤(우석) / 15,300원
# 인간 실격 / 다자이 오사무 / 8,100원
# 의사 어벤저스 25 / 고희정 / 14,220원
# Again! 뒤집어본 영문법 / 오성호 / 13,410원
# 할매 / 황석영 / 15,120원
# 원피스 ONE PIECE 113 / 오다 에이이치로 / 5,850원
# 돈의 속성 400쇄 리커버 / 김승호 / 16,020원
# 쇼펜하우어 인생수업 (30만 부 기념 개정증보판) / 쇼펜하우어 / 15,750원
# 소년이 온다 / 한강 / 13,500원
# Go Go 카카오프렌즈 39 칠레 / 김미영 / 15,210원
# 나는 소망한다 내게 금지된 것을 / 양귀자 / 13,500원
# 2026 심승아 Simple·Detail 소방학개론 심봉사 심승아 봉투 모의고사 / 심승아 / 8,100원
# ETF 투자의 모든 것 / 문일호 / 18,900원
# 편안함의 습격 / 마이클 이스터 / 19,800원
# 일본 광고 카피 도감 / 오하림 / 16,920원
# 세종의 나라 2 / 김진명 / 19,800원
# 최상위권의 생기부 / 정성민 / 40,500원
# 어른의 품격을 채우는 100일 필사 노트 / 김종원 / 18,000원
# 흔한남매 21 / 흔한남매 / 15,120원
# 해커스 보카 Hackers Vocabulary / David Cho / 15,210원
# 은애하는 도적님아 대본집 세트 / 이선 / 47,700원
# 해커스 일본어 첫걸음 히라가나 가타카나 쓰기노트 / 해커스 일본어연구소 / 7,200원
# 데일리 필로소피 / 라이언 홀리데이 / 16,200원
# 쾌적한 사회의 불쾌함 / 구마시로 도루 / 18,900원
# 2026 이유진 국어 백일기도 모의고사 [結(결) 적중] / 이유진 / 30,600원
# 달러 자산 1억으로 평생 월급 완성하라 (2026 투자 전략 특별판) / 채부심(채상욱) / 18,900원
# 행복할 거야 이래도 되나 싶을 정도로 / 일홍 / 16,200원
# 기적의 초등 신문 2026 / 강버들 / 17,820원
# 2026 선재국어 출발선 봉투 모의고사 / 이선재 / 25,200원
# 부모는 가장 좋은 입시 멘토다 / 박성오 / 16,920원
# 1984 / 조지 오웰 / 9,900원
# 2026 유휘운 행정법총론 실전동형 모의고사 / 유휘운 / 9,900원
# 절대수익 우량주 매매법 / 성경호 / 35,100원
# 규칙파괴자 / 데이비드 가드너 / 22,500원
# 하루 한 장 나의 어휘력을 위한 필사 노트 / 유선경 / 21,420원
# 스킵과 로퍼 11 더블 특전판 / 타카마츠 미사키 / 5,400원
# ETS 토익기출 파트별 VOCA 보카 / ETS / 11,700원
# 어른의 그릇 / 조윤제 / 17,100원
# 이방인 / 알베르 까뮈 / 9,000원
# 2026 이유진 국어 백일기도 모의고사 [承(승)_시간단축] / 이유진 / 25,200원
# 정답은 있다 / 이정효 / 16,200원
# 뇌는 어떻게 나를 조종하는가 / 크리스 나이바우어 / 16,920원
# 새들이 전하는 짧은 철학 / 필리프 J. 뒤부아 / 15,300원
# 2026 이유진 국어 백일기도 모의고사 [轉(전) 극한훈련] / 이유진 / 25,200원
# 눈과 돌멩이 / 위수정 / 16,200원
# 어머니의 집밥을 먹을 수 있는 횟수는 328번 남았습니다 / 우와노 소라 / 15,120원
# 반짝반짝 1학년, 학교는 널 기다려! / 전영신 / 13,050원
# 손자병법 / 손자 / 11,700원
# 김재우의 기초 영어회화 100 / 김재우 / 17,010원
# 메이지의 영원한 삶을 위해 / 크리스토퍼 엣지 / 11,700원
# 존리의 부자되기 습관 / 존리 / 18,000원
# 해커스 토익 RC Reading(리딩) 기본서 / David Cho / 16,920원
# 비실비실 선생님 11 / 후쿠치 카미오 / 5,400원
# 초판본 데미안 / 헤르만 헤세 / 1,980원
# AI 시대 십 대를 위한 논어 / 최태규 / 16,920원
# 총 균 쇠 / 재레드 다이아몬드 / 26,820원
# 두근두근 1학년, 우리는 널 사랑해! / 전영신 / 13,050원
# 몬스터 캠핑장 / 정주영 / 12,600원
# 말뚝들 / 김홍 / 15,120원
# 어린이 같은 말 다른 뜻 사전 / 박세랑 / 16,020원
# 2026 위포트 공기업 NCS 통합기본서 (PSAT형+모듈형+피듈형+실전 모의고사) / 위포트 연구소 / 24,300원
# 기분이 태도가 되지 않게 (헬로키티 에디션) / 레몬심리 / 16,200원
# 불변의 법칙 / 모건 하우절 / 22,500원

# %% [markdown]
# 1. 도서제목+저자+가격 추출
# 2. 한 페이지의 도서 목록 추출 > 리스트
# 3. 여러 페이지의 도서 목록 추출
# 4. Book 클래스를 이용한 객체 생성
# 5. sqlite db (내장 db) 저장 (예정)

# %%
import sqlite3
conn = sqlite3.connect('_books.db')
cursor = conn.cursor()

# 테이블 생성
cursor.execute('''
CREATE TABLE IF NOT EXISTS books (
    rank INTEGER PRIMARY KEY,
    title TEXT,
    author TEXT,
    price INTEGER
)
''')

# %%
# 데이터 삽입
for book in books:
    cursor.execute('''
    INSERT INTO books (title, author, price) VALUES (?, ?, ?)
    ''', (book.title, book.author, book.price))

conn.commit()
cursor.close()
conn.close()

# %%
import sqlite3
conn = sqlite3.connect('_books.db')
cursor = conn.cursor()

# %%
# 데이터 조회
cursor.execute('SELECT * FROM books')
rows = cursor.fetchall()
for row in rows:
    print(row)
    
cursor.close()
conn.close()
# Out:
# (1, '나의 완벽한 장례식', '조현선', '17,100원')
# (2, '진보를 위한 주식투자', '이광수', '19,800원')
# (3, '박곰희 연금 부자 수업', '박곰희', '18,900원')
# (4, '괴테는 모든 것을 말했다', '스즈키 유이', '15,300원')
# (5, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 RC', 'ETS', '19,800원')
# (6, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 LC', 'ETS', '19,800원')
# (7, '죽은 왕녀를 위한 파반느 (양장 특별판)', '박민규', '18,000원')
# (8, '자몽살구클럽', '한로로', '10,800원')
# (9, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상', '최태성', '17,100원')
# (10, '너를 아끼며 살아라', '나태주', '16,650원')
# (11, '모순', '양귀자', '11,700원')
# (12, '돈의 방정식', '모건 하우절', '25,200원')
# (13, '자본주의 시대에서 살아남기 위한 최소한의 경제 공부', '백억남(김욱현)', '25,200원')
# (14, '1,000만 원으로 3년 안에 300만 원 월배당 만들기', '인생업(임승현)', '20,700원')
# (15, '위버멘쉬', '프리드리히 니체', '16,020원')
# (16, '엄마가 유령이 되었어!', '노부미', '10,800원')
# (17, '안녕이라 그랬어', '김애란', '15,120원')
# (18, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하', '최태성', '16,650원')
# (19, '최소한의 삼국지', '최태성', '17,550원')
# (20, '싯다르타', '헤르만 헤세', '7,200원')
# (21, '2026 심우철 실전 동형 모의고사 Season 2', '심우철', '13,500원')
# (22, '사이토 히토리의 어떻게 살 것인가', '사이토 히토리', '11,700원')
# (23, '돈의 심리학 (50만 부 기념 뉴 에디션)', '모건 하우절', '22,320원')
# (24, '더블 클릭', '알간지', '17,100원')
# (25, '사카모토 데이즈 25 더블특전판', '스즈키 유우토', '5,850원')
# (26, '부처님 말씀대로 살아보니', '토니 페르난도', '17,010원')
# (27, '캔들차트 하나로 끝내는 추세추종 투자', '성승현', '22,500원')
# (28, '코스피 1만 넥스트 레벨', '박시동', '19,800원')
# (29, '혼모노', '성해나', '16,200원')
# (30, '해커스 토익 기출 VOCA (보카)', 'David Cho', '11,610원')
# (31, '나의 첫 월배당 ETF', '김정란', '19,800원')
# (32, '이해찬 회고록', '이해찬', '20,700원')
# (33, '설민석의 한국사 대모험 36', '설민석', '14,400원')
# (34, '코스모스', '칼 에드워드 세이건', '19,800원')
# (35, '향기로운 꽃은 늠름하게 핀다 18 더블특전판', '미카미 사카', '5,400원')
# (36, '운명을 보는 기술', '박성준', '16,920원')
# (37, '교사를 지키는 단단한 학급경영', '이종혁', '16,200원')
# (38, '어른의 행복은 조용하다', '태수', '16,020원')
# (39, '2026 써니 행정법총론 실전동형 모의고사', '박준철', '14,400원')
# (40, '2026 큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화(1,2,3급)', '최태성', '19,800원')
# (41, '주식투자 무작정 따라하기', '윤재수', '22,500원')
# (42, '절창 切創', '구병모', '16,200원')
# (43, '아주 작은 습관의 힘 (50만 부 기념 스페셜 에디션)', '제임스 클리어', '16,200원')
# (44, '2026 문동균 한국사 국가직 대비 실전 봉투 모의고사', '문동균', '11,700원')
# (45, '2026 심우철 실전 동형 모의고사 Season 1', '심우철', '13,500원')
# (46, '내가 돈을 벌고 있다는 착각', 'commonD', '17,820원')
# (47, '최소한의 한국사', '최태성', '16,200원')
# (48, '내 심장을 쏴라', '정유정', '16,200원')
# (49, '2026 선재국어 결승선 봉투 모의고사', '이선재', '25,200원')
# (50, '2026 문동균 한국사 문단속 적중 최종병기 FINAL 모의고사', '문동균', '14,400원')
# (51, '내 친구는 왜 그럴까?', '최현주', '15,120원')
# (52, '급류', '정대건', '12,600원')
# (53, '김재우의 기본 동사 100', '김재우', '19,800원')
# (54, '다크 심리학', '다크 사이드 프로젝트', '19,710원')
# (55, '해커스 일본어 첫걸음 : 일본어 기초 20일 독학 완성!', '해커스 일본어연구소', '12,510원')
# (56, 'SQL 자격검정 실전문제', '한국데이터진흥원', '17,460원')
# (57, '렛뎀 이론', '멜 로빈스', '18,000원')
# (58, '니체의 초월자', '프리드리히 니체', '15,210원')
# (59, 'ETS 토익 단기공략 750+ (LC+RC)', 'ETS', '17,550원')
# (60, '프로젝트 헤일메리 (영화 특별판)', '앤디 위어', '19,800원')
# (61, '여덟 단어', '박웅현', '15,300원')
# (62, '데일 카네기 인간관계론 (50만부 돌파 초판 무삭제 완역본)', '데일 카네기', '10,350원')
# (63, '브람스를 좋아하세요...', '프랑수아즈 사강', '9,000원')
# (64, '긴긴밤', '루리', '11,250원')
# (65, '블루 아카이브 공식 4컷 청춘? 일상! 블루 아카이브 특별판', '돈미니', '47,700원')
# (66, '2026 문동균 한국사 D-30 문단속 모의고사', '문동균', '14,400원')
# (67, '인생을 위한 최소한의 생각', '신영준', '17,820원')
# (68, '오늘 밤, 세계에서 이 사랑이 사라진다 해도', '이치조 미사키', '12,600원')
# (69, '이게 되네? 제미나이 완전 미친 활용법 81제', '오힘찬', '21,600원')
# (70, '세이노의 가르침', '세이노(SayNo)', '6,480원')
# (71, '단다단 19', '타츠 유키노부', '5,400원')
# (72, '우리는 언제나 다시 만나', '윤여림', '10,800원')
# (73, '데미안', '헤르만 헤세', '7,200원')
# (74, '체인소 맨 22', '후지모토 타츠키', '5,400원')
# (75, '이기적 유전자 The Selfish Gene', '리처드 도킨스', '18,000원')
# (76, '2026 황철곤 행정학 실전동형 모의고사 SEASON 1', '황철곤', '14,400원')
# (77, '떠난 것은 돌아오지 않는다', '줄리언 반스', '16,200원')
# (78, '신뢰 게임', '현순엽', '22,000원')
# (79, '너를 미워할 시간에 나를 사랑하기로 했다', '윤서진', '16,920원')
# (80, '세종의 나라 1', '김진명', '19,800원')
# (81, '나쁜 일이 있어도 나쁜 날은 아니야', '정문정', '15,120원')
# (82, '부의 인문학 (20만부 기념 개정증보판)', '브라운스톤(우석)', '15,300원')
# (83, '인간 실격', '다자이 오사무', '8,100원')
# (84, '의사 어벤저스 25', '고희정', '14,220원')
# (85, 'Again! 뒤집어본 영문법', '오성호', '13,410원')
# (86, '할매', '황석영', '15,120원')
# (87, '원피스 ONE PIECE 113', '오다 에이이치로', '5,850원')
# (88, '돈의 속성 400쇄 리커버', '김승호', '16,020원')
# (89, '쇼펜하우어 인생수업 (30만 부 기념 개정증보판)', '쇼펜하우어', '15,750원')
# (90, '소년이 온다', '한강', '13,500원')
# (91, 'Go Go 카카오프렌즈 39 칠레', '김미영', '15,210원')
# (92, '나는 소망한다 내게 금지된 것을', '양귀자', '13,500원')
# (93, '2026 심승아 Simple·Detail 소방학개론 심봉사 심승아 봉투 모의고사', '심승아', '8,100원')
# (94, 'ETF 투자의 모든 것', '문일호', '18,900원')
# (95, '편안함의 습격', '마이클 이스터', '19,800원')
# (96, '일본 광고 카피 도감', '오하림', '16,920원')
# (97, '세종의 나라 2', '김진명', '19,800원')
# (98, '최상위권의 생기부', '정성민', '40,500원')
# (99, '어른의 품격을 채우는 100일 필사 노트', '김종원', '18,000원')
# (100, '흔한남매 21', '흔한남매', '15,120원')
# (101, '해커스 보카 Hackers Vocabulary', 'David Cho', '15,210원')
# (102, '은애하는 도적님아 대본집 세트', '이선', '47,700원')
# (103, '해커스 일본어 첫걸음 히라가나 가타카나 쓰기노트', '해커스 일본어연구소', '7,200원')
# (104, '데일리 필로소피', '라이언 홀리데이', '16,200원')
# (105, '쾌적한 사회의 불쾌함', '구마시로 도루', '18,900원')
# (106, '2026 이유진 국어 백일기도 모의고사 [結(결) 적중]', '이유진', '30,600원')
# (107, '달러 자산 1억으로 평생 월급 완성하라 (2026 투자 전략 특별판)', '채부심(채상욱)', '18,900원')
# (108, '행복할 거야 이래도 되나 싶을 정도로', '일홍', '16,200원')
# (109, '기적의 초등 신문 2026', '강버들', '17,820원')
# (110, '2026 선재국어 출발선 봉투 모의고사', '이선재', '25,200원')
# (111, '부모는 가장 좋은 입시 멘토다', '박성오', '16,920원')
# (112, '1984', '조지 오웰', '9,900원')
# (113, '2026 유휘운 행정법총론 실전동형 모의고사', '유휘운', '9,900원')
# (114, '절대수익 우량주 매매법', '성경호', '35,100원')
# (115, '규칙파괴자', '데이비드 가드너', '22,500원')
# (116, '하루 한 장 나의 어휘력을 위한 필사 노트', '유선경', '21,420원')
# (117, '스킵과 로퍼 11 더블 특전판', '타카마츠 미사키', '5,400원')
# (118, 'ETS 토익기출 파트별 VOCA 보카', 'ETS', '11,700원')
# (119, '어른의 그릇', '조윤제', '17,100원')
# (120, '이방인', '알베르 까뮈', '9,000원')
# (121, '2026 이유진 국어 백일기도 모의고사 [承(승)_시간단축]', '이유진', '25,200원')
# (122, '정답은 있다', '이정효', '16,200원')
# (123, '뇌는 어떻게 나를 조종하는가', '크리스 나이바우어', '16,920원')
# (124, '새들이 전하는 짧은 철학', '필리프 J. 뒤부아', '15,300원')
# (125, '2026 이유진 국어 백일기도 모의고사 [轉(전) 극한훈련]', '이유진', '25,200원')
# (126, '눈과 돌멩이', '위수정', '16,200원')
# (127, '어머니의 집밥을 먹을 수 있는 횟수는 328번 남았습니다', '우와노 소라', '15,120원')
# (128, '반짝반짝 1학년, 학교는 널 기다려!', '전영신', '13,050원')
# (129, '손자병법', '손자', '11,700원')
# (130, '김재우의 기초 영어회화 100', '김재우', '17,010원')
# (131, '메이지의 영원한 삶을 위해', '크리스토퍼 엣지', '11,700원')
# (132, '존리의 부자되기 습관', '존리', '18,000원')
# (133, '해커스 토익 RC Reading(리딩) 기본서', 'David Cho', '16,920원')
# (134, '비실비실 선생님 11', '후쿠치 카미오', '5,400원')
# (135, '초판본 데미안', '헤르만 헤세', '1,980원')
# (136, 'AI 시대 십 대를 위한 논어', '최태규', '16,920원')
# (137, '총 균 쇠', '재레드 다이아몬드', '26,820원')
# (138, '두근두근 1학년, 우리는 널 사랑해!', '전영신', '13,050원')
# (139, '몬스터 캠핑장', '정주영', '12,600원')
# (140, '말뚝들', '김홍', '15,120원')
# (141, '어린이 같은 말 다른 뜻 사전', '박세랑', '16,020원')
# (142, '2026 위포트 공기업 NCS 통합기본서 (PSAT형+모듈형+피듈형+실전 모의고사)', '위포트 연구소', '24,300원')
# (143, '기분이 태도가 되지 않게 (헬로키티 에디션)', '레몬심리', '16,200원')
# (144, '불변의 법칙', '모건 하우절', '22,500원')
# (145, '나의 완벽한 장례식', '조현선', '17,100원')
# (146, '진보를 위한 주식투자', '이광수', '19,800원')
# (147, '박곰희 연금 부자 수업', '박곰희', '18,900원')
# (148, '괴테는 모든 것을 말했다', '스즈키 유이', '15,300원')
# (149, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 RC', 'ETS', '19,800원')
# (150, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 LC', 'ETS', '19,800원')
# (151, '죽은 왕녀를 위한 파반느 (양장 특별판)', '박민규', '18,000원')
# (152, '자몽살구클럽', '한로로', '10,800원')
# (153, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상', '최태성', '17,100원')
# (154, '너를 아끼며 살아라', '나태주', '16,650원')
# (155, '모순', '양귀자', '11,700원')
# (156, '돈의 방정식', '모건 하우절', '25,200원')
# (157, '자본주의 시대에서 살아남기 위한 최소한의 경제 공부', '백억남(김욱현)', '25,200원')
# (158, '1,000만 원으로 3년 안에 300만 원 월배당 만들기', '인생업(임승현)', '20,700원')
# (159, '위버멘쉬', '프리드리히 니체', '16,020원')
# (160, '엄마가 유령이 되었어!', '노부미', '10,800원')
# (161, '안녕이라 그랬어', '김애란', '15,120원')
# (162, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하', '최태성', '16,650원')
# (163, '최소한의 삼국지', '최태성', '17,550원')
# (164, '싯다르타', '헤르만 헤세', '7,200원')
# (165, '2026 심우철 실전 동형 모의고사 Season 2', '심우철', '13,500원')
# (166, '사이토 히토리의 어떻게 살 것인가', '사이토 히토리', '11,700원')
# (167, '돈의 심리학 (50만 부 기념 뉴 에디션)', '모건 하우절', '22,320원')
# (168, '더블 클릭', '알간지', '17,100원')
# (169, '사카모토 데이즈 25 더블특전판', '스즈키 유우토', '5,850원')
# (170, '부처님 말씀대로 살아보니', '토니 페르난도', '17,010원')
# (171, '캔들차트 하나로 끝내는 추세추종 투자', '성승현', '22,500원')
# (172, '코스피 1만 넥스트 레벨', '박시동', '19,800원')
# (173, '혼모노', '성해나', '16,200원')
# (174, '해커스 토익 기출 VOCA (보카)', 'David Cho', '11,610원')
# (175, '나의 첫 월배당 ETF', '김정란', '19,800원')
# (176, '이해찬 회고록', '이해찬', '20,700원')
# (177, '설민석의 한국사 대모험 36', '설민석', '14,400원')
# (178, '코스모스', '칼 에드워드 세이건', '19,800원')
# (179, '향기로운 꽃은 늠름하게 핀다 18 더블특전판', '미카미 사카', '5,400원')
# (180, '운명을 보는 기술', '박성준', '16,920원')
# (181, '교사를 지키는 단단한 학급경영', '이종혁', '16,200원')
# (182, '어른의 행복은 조용하다', '태수', '16,020원')
# (183, '2026 써니 행정법총론 실전동형 모의고사', '박준철', '14,400원')
# (184, '2026 큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화(1,2,3급)', '최태성', '19,800원')
# (185, '주식투자 무작정 따라하기', '윤재수', '22,500원')
# (186, '절창 切創', '구병모', '16,200원')
# (187, '아주 작은 습관의 힘 (50만 부 기념 스페셜 에디션)', '제임스 클리어', '16,200원')
# (188, '2026 문동균 한국사 국가직 대비 실전 봉투 모의고사', '문동균', '11,700원')
# (189, '2026 심우철 실전 동형 모의고사 Season 1', '심우철', '13,500원')
# (190, '내가 돈을 벌고 있다는 착각', 'commonD', '17,820원')
# (191, '최소한의 한국사', '최태성', '16,200원')
# (192, '내 심장을 쏴라', '정유정', '16,200원')
# (193, '2026 선재국어 결승선 봉투 모의고사', '이선재', '25,200원')
# (194, '2026 문동균 한국사 문단속 적중 최종병기 FINAL 모의고사', '문동균', '14,400원')
# (195, '내 친구는 왜 그럴까?', '최현주', '15,120원')
# (196, '급류', '정대건', '12,600원')
# (197, '김재우의 기본 동사 100', '김재우', '19,800원')
# (198, '다크 심리학', '다크 사이드 프로젝트', '19,710원')
# (199, '해커스 일본어 첫걸음 : 일본어 기초 20일 독학 완성!', '해커스 일본어연구소', '12,510원')
# (200, 'SQL 자격검정 실전문제', '한국데이터진흥원', '17,460원')
# (201, '렛뎀 이론', '멜 로빈스', '18,000원')
# (202, '니체의 초월자', '프리드리히 니체', '15,210원')
# (203, 'ETS 토익 단기공략 750+ (LC+RC)', 'ETS', '17,550원')
# (204, '프로젝트 헤일메리 (영화 특별판)', '앤디 위어', '19,800원')
# (205, '여덟 단어', '박웅현', '15,300원')
# (206, '데일 카네기 인간관계론 (50만부 돌파 초판 무삭제 완역본)', '데일 카네기', '10,350원')
# (207, '브람스를 좋아하세요...', '프랑수아즈 사강', '9,000원')
# (208, '긴긴밤', '루리', '11,250원')
# (209, '블루 아카이브 공식 4컷 청춘? 일상! 블루 아카이브 특별판', '돈미니', '47,700원')
# (210, '2026 문동균 한국사 D-30 문단속 모의고사', '문동균', '14,400원')
# (211, '인생을 위한 최소한의 생각', '신영준', '17,820원')
# (212, '오늘 밤, 세계에서 이 사랑이 사라진다 해도', '이치조 미사키', '12,600원')
# (213, '이게 되네? 제미나이 완전 미친 활용법 81제', '오힘찬', '21,600원')
# (214, '세이노의 가르침', '세이노(SayNo)', '6,480원')
# (215, '단다단 19', '타츠 유키노부', '5,400원')
# (216, '우리는 언제나 다시 만나', '윤여림', '10,800원')
# (217, '데미안', '헤르만 헤세', '7,200원')
# (218, '체인소 맨 22', '후지모토 타츠키', '5,400원')
# (219, '이기적 유전자 The Selfish Gene', '리처드 도킨스', '18,000원')
# (220, '2026 황철곤 행정학 실전동형 모의고사 SEASON 1', '황철곤', '14,400원')
# (221, '떠난 것은 돌아오지 않는다', '줄리언 반스', '16,200원')
# (222, '신뢰 게임', '현순엽', '22,000원')
# (223, '너를 미워할 시간에 나를 사랑하기로 했다', '윤서진', '16,920원')
# (224, '세종의 나라 1', '김진명', '19,800원')
# (225, '나쁜 일이 있어도 나쁜 날은 아니야', '정문정', '15,120원')
# (226, '부의 인문학 (20만부 기념 개정증보판)', '브라운스톤(우석)', '15,300원')
# (227, '인간 실격', '다자이 오사무', '8,100원')
# (228, '의사 어벤저스 25', '고희정', '14,220원')
# (229, 'Again! 뒤집어본 영문법', '오성호', '13,410원')
# (230, '할매', '황석영', '15,120원')
# (231, '원피스 ONE PIECE 113', '오다 에이이치로', '5,850원')
# (232, '돈의 속성 400쇄 리커버', '김승호', '16,020원')
# (233, '쇼펜하우어 인생수업 (30만 부 기념 개정증보판)', '쇼펜하우어', '15,750원')
# (234, '소년이 온다', '한강', '13,500원')
# (235, 'Go Go 카카오프렌즈 39 칠레', '김미영', '15,210원')
# (236, '나는 소망한다 내게 금지된 것을', '양귀자', '13,500원')
# (237, '2026 심승아 Simple·Detail 소방학개론 심봉사 심승아 봉투 모의고사', '심승아', '8,100원')
# (238, 'ETF 투자의 모든 것', '문일호', '18,900원')
# (239, '편안함의 습격', '마이클 이스터', '19,800원')
# (240, '일본 광고 카피 도감', '오하림', '16,920원')
# (241, '세종의 나라 2', '김진명', '19,800원')
# (242, '최상위권의 생기부', '정성민', '40,500원')
# (243, '어른의 품격을 채우는 100일 필사 노트', '김종원', '18,000원')
# (244, '흔한남매 21', '흔한남매', '15,120원')
# (245, '해커스 보카 Hackers Vocabulary', 'David Cho', '15,210원')
# (246, '은애하는 도적님아 대본집 세트', '이선', '47,700원')
# (247, '해커스 일본어 첫걸음 히라가나 가타카나 쓰기노트', '해커스 일본어연구소', '7,200원')
# (248, '데일리 필로소피', '라이언 홀리데이', '16,200원')
# (249, '쾌적한 사회의 불쾌함', '구마시로 도루', '18,900원')
# (250, '2026 이유진 국어 백일기도 모의고사 [結(결) 적중]', '이유진', '30,600원')
# (251, '달러 자산 1억으로 평생 월급 완성하라 (2026 투자 전략 특별판)', '채부심(채상욱)', '18,900원')
# (252, '행복할 거야 이래도 되나 싶을 정도로', '일홍', '16,200원')
# (253, '기적의 초등 신문 2026', '강버들', '17,820원')
# (254, '2026 선재국어 출발선 봉투 모의고사', '이선재', '25,200원')
# (255, '부모는 가장 좋은 입시 멘토다', '박성오', '16,920원')
# (256, '1984', '조지 오웰', '9,900원')
# (257, '2026 유휘운 행정법총론 실전동형 모의고사', '유휘운', '9,900원')
# (258, '절대수익 우량주 매매법', '성경호', '35,100원')
# (259, '규칙파괴자', '데이비드 가드너', '22,500원')
# (260, '하루 한 장 나의 어휘력을 위한 필사 노트', '유선경', '21,420원')
# (261, '스킵과 로퍼 11 더블 특전판', '타카마츠 미사키', '5,400원')
# (262, 'ETS 토익기출 파트별 VOCA 보카', 'ETS', '11,700원')
# (263, '어른의 그릇', '조윤제', '17,100원')
# (264, '이방인', '알베르 까뮈', '9,000원')
# (265, '2026 이유진 국어 백일기도 모의고사 [承(승)_시간단축]', '이유진', '25,200원')
# (266, '정답은 있다', '이정효', '16,200원')
# (267, '뇌는 어떻게 나를 조종하는가', '크리스 나이바우어', '16,920원')
# (268, '새들이 전하는 짧은 철학', '필리프 J. 뒤부아', '15,300원')
# (269, '2026 이유진 국어 백일기도 모의고사 [轉(전) 극한훈련]', '이유진', '25,200원')
# (270, '눈과 돌멩이', '위수정', '16,200원')
# (271, '어머니의 집밥을 먹을 수 있는 횟수는 328번 남았습니다', '우와노 소라', '15,120원')
# (272, '반짝반짝 1학년, 학교는 널 기다려!', '전영신', '13,050원')
# (273, '손자병법', '손자', '11,700원')
# (274, '김재우의 기초 영어회화 100', '김재우', '17,010원')
# (275, '메이지의 영원한 삶을 위해', '크리스토퍼 엣지', '11,700원')
# (276, '존리의 부자되기 습관', '존리', '18,000원')
# (277, '해커스 토익 RC Reading(리딩) 기본서', 'David Cho', '16,920원')
# (278, '비실비실 선생님 11', '후쿠치 카미오', '5,400원')
# (279, '초판본 데미안', '헤르만 헤세', '1,980원')
# (280, 'AI 시대 십 대를 위한 논어', '최태규', '16,920원')
# (281, '총 균 쇠', '재레드 다이아몬드', '26,820원')
# (282, '두근두근 1학년, 우리는 널 사랑해!', '전영신', '13,050원')
# (283, '몬스터 캠핑장', '정주영', '12,600원')
# (284, '말뚝들', '김홍', '15,120원')
# (285, '어린이 같은 말 다른 뜻 사전', '박세랑', '16,020원')
# (286, '2026 위포트 공기업 NCS 통합기본서 (PSAT형+모듈형+피듈형+실전 모의고사)', '위포트 연구소', '24,300원')
# (287, '기분이 태도가 되지 않게 (헬로키티 에디션)', '레몬심리', '16,200원')
# (288, '불변의 법칙', '모건 하우절', '22,500원')
# (289, '나의 완벽한 장례식', '조현선', '17,100원')
# (290, '진보를 위한 주식투자', '이광수', '19,800원')
# (291, '박곰희 연금 부자 수업', '박곰희', '18,900원')
# (292, '괴테는 모든 것을 말했다', '스즈키 유이', '15,300원')
# (293, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 RC', 'ETS', '19,800원')
# (294, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 LC', 'ETS', '19,800원')
# (295, '죽은 왕녀를 위한 파반느 (양장 특별판)', '박민규', '18,000원')
# (296, '자몽살구클럽', '한로로', '10,800원')
# (297, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상', '최태성', '17,100원')
# (298, '너를 아끼며 살아라', '나태주', '16,650원')
# (299, '모순', '양귀자', '11,700원')
# (300, '돈의 방정식', '모건 하우절', '25,200원')
# (301, '자본주의 시대에서 살아남기 위한 최소한의 경제 공부', '백억남(김욱현)', '25,200원')
# (302, '1,000만 원으로 3년 안에 300만 원 월배당 만들기', '인생업(임승현)', '20,700원')
# (303, '위버멘쉬', '프리드리히 니체', '16,020원')
# (304, '엄마가 유령이 되었어!', '노부미', '10,800원')
# (305, '안녕이라 그랬어', '김애란', '15,120원')
# (306, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하', '최태성', '16,650원')
# (307, '최소한의 삼국지', '최태성', '17,550원')
# (308, '싯다르타', '헤르만 헤세', '7,200원')
# (309, '2026 심우철 실전 동형 모의고사 Season 2', '심우철', '13,500원')
# (310, '사이토 히토리의 어떻게 살 것인가', '사이토 히토리', '11,700원')
# (311, '돈의 심리학 (50만 부 기념 뉴 에디션)', '모건 하우절', '22,320원')
# (312, '더블 클릭', '알간지', '17,100원')
# (313, '사카모토 데이즈 25 더블특전판', '스즈키 유우토', '5,850원')
# (314, '부처님 말씀대로 살아보니', '토니 페르난도', '17,010원')
# (315, '캔들차트 하나로 끝내는 추세추종 투자', '성승현', '22,500원')
# (316, '코스피 1만 넥스트 레벨', '박시동', '19,800원')
# (317, '혼모노', '성해나', '16,200원')
# (318, '해커스 토익 기출 VOCA (보카)', 'David Cho', '11,610원')
# (319, '나의 첫 월배당 ETF', '김정란', '19,800원')
# (320, '이해찬 회고록', '이해찬', '20,700원')
# (321, '설민석의 한국사 대모험 36', '설민석', '14,400원')
# (322, '코스모스', '칼 에드워드 세이건', '19,800원')
# (323, '향기로운 꽃은 늠름하게 핀다 18 더블특전판', '미카미 사카', '5,400원')
# (324, '운명을 보는 기술', '박성준', '16,920원')
# (325, '교사를 지키는 단단한 학급경영', '이종혁', '16,200원')
# (326, '어른의 행복은 조용하다', '태수', '16,020원')
# (327, '2026 써니 행정법총론 실전동형 모의고사', '박준철', '14,400원')
# (328, '2026 큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화(1,2,3급)', '최태성', '19,800원')
# (329, '주식투자 무작정 따라하기', '윤재수', '22,500원')
# (330, '절창 切創', '구병모', '16,200원')
# (331, '아주 작은 습관의 힘 (50만 부 기념 스페셜 에디션)', '제임스 클리어', '16,200원')
# (332, '2026 문동균 한국사 국가직 대비 실전 봉투 모의고사', '문동균', '11,700원')
# (333, '2026 심우철 실전 동형 모의고사 Season 1', '심우철', '13,500원')
# (334, '내가 돈을 벌고 있다는 착각', 'commonD', '17,820원')
# (335, '최소한의 한국사', '최태성', '16,200원')
# (336, '내 심장을 쏴라', '정유정', '16,200원')
# (337, '2026 선재국어 결승선 봉투 모의고사', '이선재', '25,200원')
# (338, '2026 문동균 한국사 문단속 적중 최종병기 FINAL 모의고사', '문동균', '14,400원')
# (339, '내 친구는 왜 그럴까?', '최현주', '15,120원')
# (340, '급류', '정대건', '12,600원')
# (341, '김재우의 기본 동사 100', '김재우', '19,800원')
# (342, '다크 심리학', '다크 사이드 프로젝트', '19,710원')
# (343, '해커스 일본어 첫걸음 : 일본어 기초 20일 독학 완성!', '해커스 일본어연구소', '12,510원')
# (344, 'SQL 자격검정 실전문제', '한국데이터진흥원', '17,460원')
# (345, '렛뎀 이론', '멜 로빈스', '18,000원')
# (346, '니체의 초월자', '프리드리히 니체', '15,210원')
# (347, 'ETS 토익 단기공략 750+ (LC+RC)', 'ETS', '17,550원')
# (348, '프로젝트 헤일메리 (영화 특별판)', '앤디 위어', '19,800원')
# (349, '여덟 단어', '박웅현', '15,300원')
# (350, '데일 카네기 인간관계론 (50만부 돌파 초판 무삭제 완역본)', '데일 카네기', '10,350원')
# (351, '브람스를 좋아하세요...', '프랑수아즈 사강', '9,000원')
# (352, '긴긴밤', '루리', '11,250원')
# (353, '블루 아카이브 공식 4컷 청춘? 일상! 블루 아카이브 특별판', '돈미니', '47,700원')
# (354, '2026 문동균 한국사 D-30 문단속 모의고사', '문동균', '14,400원')
# (355, '인생을 위한 최소한의 생각', '신영준', '17,820원')
# (356, '오늘 밤, 세계에서 이 사랑이 사라진다 해도', '이치조 미사키', '12,600원')
# (357, '이게 되네? 제미나이 완전 미친 활용법 81제', '오힘찬', '21,600원')
# (358, '세이노의 가르침', '세이노(SayNo)', '6,480원')
# (359, '단다단 19', '타츠 유키노부', '5,400원')
# (360, '우리는 언제나 다시 만나', '윤여림', '10,800원')
# (361, '데미안', '헤르만 헤세', '7,200원')
# (362, '체인소 맨 22', '후지모토 타츠키', '5,400원')
# (363, '이기적 유전자 The Selfish Gene', '리처드 도킨스', '18,000원')
# (364, '2026 황철곤 행정학 실전동형 모의고사 SEASON 1', '황철곤', '14,400원')
# (365, '떠난 것은 돌아오지 않는다', '줄리언 반스', '16,200원')
# (366, '신뢰 게임', '현순엽', '22,000원')
# (367, '너를 미워할 시간에 나를 사랑하기로 했다', '윤서진', '16,920원')
# (368, '세종의 나라 1', '김진명', '19,800원')
# (369, '나쁜 일이 있어도 나쁜 날은 아니야', '정문정', '15,120원')
# (370, '부의 인문학 (20만부 기념 개정증보판)', '브라운스톤(우석)', '15,300원')
# (371, '인간 실격', '다자이 오사무', '8,100원')
# (372, '의사 어벤저스 25', '고희정', '14,220원')
# (373, 'Again! 뒤집어본 영문법', '오성호', '13,410원')
# (374, '할매', '황석영', '15,120원')
# (375, '원피스 ONE PIECE 113', '오다 에이이치로', '5,850원')
# (376, '돈의 속성 400쇄 리커버', '김승호', '16,020원')
# (377, '쇼펜하우어 인생수업 (30만 부 기념 개정증보판)', '쇼펜하우어', '15,750원')
# (378, '소년이 온다', '한강', '13,500원')
# (379, 'Go Go 카카오프렌즈 39 칠레', '김미영', '15,210원')
# (380, '나는 소망한다 내게 금지된 것을', '양귀자', '13,500원')
# (381, '2026 심승아 Simple·Detail 소방학개론 심봉사 심승아 봉투 모의고사', '심승아', '8,100원')
# (382, 'ETF 투자의 모든 것', '문일호', '18,900원')
# (383, '편안함의 습격', '마이클 이스터', '19,800원')
# (384, '일본 광고 카피 도감', '오하림', '16,920원')
# (385, '세종의 나라 2', '김진명', '19,800원')
# (386, '최상위권의 생기부', '정성민', '40,500원')
# (387, '어른의 품격을 채우는 100일 필사 노트', '김종원', '18,000원')
# (388, '흔한남매 21', '흔한남매', '15,120원')
# (389, '해커스 보카 Hackers Vocabulary', 'David Cho', '15,210원')
# (390, '은애하는 도적님아 대본집 세트', '이선', '47,700원')
# (391, '해커스 일본어 첫걸음 히라가나 가타카나 쓰기노트', '해커스 일본어연구소', '7,200원')
# (392, '데일리 필로소피', '라이언 홀리데이', '16,200원')
# (393, '쾌적한 사회의 불쾌함', '구마시로 도루', '18,900원')
# (394, '2026 이유진 국어 백일기도 모의고사 [結(결) 적중]', '이유진', '30,600원')
# (395, '달러 자산 1억으로 평생 월급 완성하라 (2026 투자 전략 특별판)', '채부심(채상욱)', '18,900원')
# (396, '행복할 거야 이래도 되나 싶을 정도로', '일홍', '16,200원')
# (397, '기적의 초등 신문 2026', '강버들', '17,820원')
# (398, '2026 선재국어 출발선 봉투 모의고사', '이선재', '25,200원')
# (399, '부모는 가장 좋은 입시 멘토다', '박성오', '16,920원')
# (400, '1984', '조지 오웰', '9,900원')
# (401, '2026 유휘운 행정법총론 실전동형 모의고사', '유휘운', '9,900원')
# (402, '절대수익 우량주 매매법', '성경호', '35,100원')
# (403, '규칙파괴자', '데이비드 가드너', '22,500원')
# (404, '하루 한 장 나의 어휘력을 위한 필사 노트', '유선경', '21,420원')
# (405, '스킵과 로퍼 11 더블 특전판', '타카마츠 미사키', '5,400원')
# (406, 'ETS 토익기출 파트별 VOCA 보카', 'ETS', '11,700원')
# (407, '어른의 그릇', '조윤제', '17,100원')
# (408, '이방인', '알베르 까뮈', '9,000원')
# (409, '2026 이유진 국어 백일기도 모의고사 [承(승)_시간단축]', '이유진', '25,200원')
# (410, '정답은 있다', '이정효', '16,200원')
# (411, '뇌는 어떻게 나를 조종하는가', '크리스 나이바우어', '16,920원')
# (412, '새들이 전하는 짧은 철학', '필리프 J. 뒤부아', '15,300원')
# (413, '2026 이유진 국어 백일기도 모의고사 [轉(전) 극한훈련]', '이유진', '25,200원')
# (414, '눈과 돌멩이', '위수정', '16,200원')
# (415, '어머니의 집밥을 먹을 수 있는 횟수는 328번 남았습니다', '우와노 소라', '15,120원')
# (416, '반짝반짝 1학년, 학교는 널 기다려!', '전영신', '13,050원')
# (417, '손자병법', '손자', '11,700원')
# (418, '김재우의 기초 영어회화 100', '김재우', '17,010원')
# (419, '메이지의 영원한 삶을 위해', '크리스토퍼 엣지', '11,700원')
# (420, '존리의 부자되기 습관', '존리', '18,000원')
# (421, '해커스 토익 RC Reading(리딩) 기본서', 'David Cho', '16,920원')
# (422, '비실비실 선생님 11', '후쿠치 카미오', '5,400원')
# (423, '초판본 데미안', '헤르만 헤세', '1,980원')
# (424, 'AI 시대 십 대를 위한 논어', '최태규', '16,920원')
# (425, '총 균 쇠', '재레드 다이아몬드', '26,820원')
# (426, '두근두근 1학년, 우리는 널 사랑해!', '전영신', '13,050원')
# (427, '몬스터 캠핑장', '정주영', '12,600원')
# (428, '말뚝들', '김홍', '15,120원')
# (429, '어린이 같은 말 다른 뜻 사전', '박세랑', '16,020원')
# (430, '2026 위포트 공기업 NCS 통합기본서 (PSAT형+모듈형+피듈형+실전 모의고사)', '위포트 연구소', '24,300원')
# (431, '기분이 태도가 되지 않게 (헬로키티 에디션)', '레몬심리', '16,200원')
# (432, '불변의 법칙', '모건 하우절', '22,500원')
# (433, '나의 완벽한 장례식', '조현선', '17,100원')
# (434, '진보를 위한 주식투자', '이광수', '19,800원')
# (435, '박곰희 연금 부자 수업', '박곰희', '18,900원')
# (436, '괴테는 모든 것을 말했다', '스즈키 유이', '15,300원')
# (437, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 RC', 'ETS', '19,800원')
# (438, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 LC', 'ETS', '19,800원')
# (439, '죽은 왕녀를 위한 파반느 (양장 특별판)', '박민규', '18,000원')
# (440, '자몽살구클럽', '한로로', '10,800원')
# (441, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상', '최태성', '17,100원')
# (442, '너를 아끼며 살아라', '나태주', '16,650원')
# (443, '모순', '양귀자', '11,700원')
# (444, '돈의 방정식', '모건 하우절', '25,200원')
# (445, '자본주의 시대에서 살아남기 위한 최소한의 경제 공부', '백억남(김욱현)', '25,200원')
# (446, '1,000만 원으로 3년 안에 300만 원 월배당 만들기', '인생업(임승현)', '20,700원')
# (447, '위버멘쉬', '프리드리히 니체', '16,020원')
# (448, '엄마가 유령이 되었어!', '노부미', '10,800원')
# (449, '안녕이라 그랬어', '김애란', '15,120원')
# (450, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하', '최태성', '16,650원')
# (451, '최소한의 삼국지', '최태성', '17,550원')
# (452, '싯다르타', '헤르만 헤세', '7,200원')
# (453, '2026 심우철 실전 동형 모의고사 Season 2', '심우철', '13,500원')
# (454, '사이토 히토리의 어떻게 살 것인가', '사이토 히토리', '11,700원')
# (455, '돈의 심리학 (50만 부 기념 뉴 에디션)', '모건 하우절', '22,320원')
# (456, '더블 클릭', '알간지', '17,100원')
# (457, '사카모토 데이즈 25 더블특전판', '스즈키 유우토', '5,850원')
# (458, '부처님 말씀대로 살아보니', '토니 페르난도', '17,010원')
# (459, '캔들차트 하나로 끝내는 추세추종 투자', '성승현', '22,500원')
# (460, '코스피 1만 넥스트 레벨', '박시동', '19,800원')
# (461, '혼모노', '성해나', '16,200원')
# (462, '해커스 토익 기출 VOCA (보카)', 'David Cho', '11,610원')
# (463, '나의 첫 월배당 ETF', '김정란', '19,800원')
# (464, '이해찬 회고록', '이해찬', '20,700원')
# (465, '설민석의 한국사 대모험 36', '설민석', '14,400원')
# (466, '코스모스', '칼 에드워드 세이건', '19,800원')
# (467, '향기로운 꽃은 늠름하게 핀다 18 더블특전판', '미카미 사카', '5,400원')
# (468, '운명을 보는 기술', '박성준', '16,920원')
# (469, '교사를 지키는 단단한 학급경영', '이종혁', '16,200원')
# (470, '어른의 행복은 조용하다', '태수', '16,020원')
# (471, '2026 써니 행정법총론 실전동형 모의고사', '박준철', '14,400원')
# (472, '2026 큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화(1,2,3급)', '최태성', '19,800원')
# (473, '주식투자 무작정 따라하기', '윤재수', '22,500원')
# (474, '절창 切創', '구병모', '16,200원')
# (475, '아주 작은 습관의 힘 (50만 부 기념 스페셜 에디션)', '제임스 클리어', '16,200원')
# (476, '2026 문동균 한국사 국가직 대비 실전 봉투 모의고사', '문동균', '11,700원')
# (477, '2026 심우철 실전 동형 모의고사 Season 1', '심우철', '13,500원')
# (478, '내가 돈을 벌고 있다는 착각', 'commonD', '17,820원')
# (479, '최소한의 한국사', '최태성', '16,200원')
# (480, '내 심장을 쏴라', '정유정', '16,200원')
# (481, '2026 선재국어 결승선 봉투 모의고사', '이선재', '25,200원')
# (482, '2026 문동균 한국사 문단속 적중 최종병기 FINAL 모의고사', '문동균', '14,400원')
# (483, '내 친구는 왜 그럴까?', '최현주', '15,120원')
# (484, '급류', '정대건', '12,600원')
# (485, '김재우의 기본 동사 100', '김재우', '19,800원')
# (486, '다크 심리학', '다크 사이드 프로젝트', '19,710원')
# (487, '해커스 일본어 첫걸음 : 일본어 기초 20일 독학 완성!', '해커스 일본어연구소', '12,510원')
# (488, 'SQL 자격검정 실전문제', '한국데이터진흥원', '17,460원')
# (489, '렛뎀 이론', '멜 로빈스', '18,000원')
# (490, '니체의 초월자', '프리드리히 니체', '15,210원')
# (491, 'ETS 토익 단기공략 750+ (LC+RC)', 'ETS', '17,550원')
# (492, '프로젝트 헤일메리 (영화 특별판)', '앤디 위어', '19,800원')
# (493, '여덟 단어', '박웅현', '15,300원')
# (494, '데일 카네기 인간관계론 (50만부 돌파 초판 무삭제 완역본)', '데일 카네기', '10,350원')
# (495, '브람스를 좋아하세요...', '프랑수아즈 사강', '9,000원')
# (496, '긴긴밤', '루리', '11,250원')
# (497, '블루 아카이브 공식 4컷 청춘? 일상! 블루 아카이브 특별판', '돈미니', '47,700원')
# (498, '2026 문동균 한국사 D-30 문단속 모의고사', '문동균', '14,400원')
# (499, '인생을 위한 최소한의 생각', '신영준', '17,820원')
# (500, '오늘 밤, 세계에서 이 사랑이 사라진다 해도', '이치조 미사키', '12,600원')
# (501, '이게 되네? 제미나이 완전 미친 활용법 81제', '오힘찬', '21,600원')
# (502, '세이노의 가르침', '세이노(SayNo)', '6,480원')
# (503, '단다단 19', '타츠 유키노부', '5,400원')
# (504, '우리는 언제나 다시 만나', '윤여림', '10,800원')
# (505, '데미안', '헤르만 헤세', '7,200원')
# (506, '체인소 맨 22', '후지모토 타츠키', '5,400원')
# (507, '이기적 유전자 The Selfish Gene', '리처드 도킨스', '18,000원')
# (508, '2026 황철곤 행정학 실전동형 모의고사 SEASON 1', '황철곤', '14,400원')
# (509, '떠난 것은 돌아오지 않는다', '줄리언 반스', '16,200원')
# (510, '신뢰 게임', '현순엽', '22,000원')
# (511, '너를 미워할 시간에 나를 사랑하기로 했다', '윤서진', '16,920원')
# (512, '세종의 나라 1', '김진명', '19,800원')
# (513, '나쁜 일이 있어도 나쁜 날은 아니야', '정문정', '15,120원')
# (514, '부의 인문학 (20만부 기념 개정증보판)', '브라운스톤(우석)', '15,300원')
# (515, '인간 실격', '다자이 오사무', '8,100원')
# (516, '의사 어벤저스 25', '고희정', '14,220원')
# (517, 'Again! 뒤집어본 영문법', '오성호', '13,410원')
# (518, '할매', '황석영', '15,120원')
# (519, '원피스 ONE PIECE 113', '오다 에이이치로', '5,850원')
# (520, '돈의 속성 400쇄 리커버', '김승호', '16,020원')
# (521, '쇼펜하우어 인생수업 (30만 부 기념 개정증보판)', '쇼펜하우어', '15,750원')
# (522, '소년이 온다', '한강', '13,500원')
# (523, 'Go Go 카카오프렌즈 39 칠레', '김미영', '15,210원')
# (524, '나는 소망한다 내게 금지된 것을', '양귀자', '13,500원')
# (525, '2026 심승아 Simple·Detail 소방학개론 심봉사 심승아 봉투 모의고사', '심승아', '8,100원')
# (526, 'ETF 투자의 모든 것', '문일호', '18,900원')
# (527, '편안함의 습격', '마이클 이스터', '19,800원')
# (528, '일본 광고 카피 도감', '오하림', '16,920원')
# (529, '세종의 나라 2', '김진명', '19,800원')
# (530, '최상위권의 생기부', '정성민', '40,500원')
# (531, '어른의 품격을 채우는 100일 필사 노트', '김종원', '18,000원')
# (532, '흔한남매 21', '흔한남매', '15,120원')
# (533, '해커스 보카 Hackers Vocabulary', 'David Cho', '15,210원')
# (534, '은애하는 도적님아 대본집 세트', '이선', '47,700원')
# (535, '해커스 일본어 첫걸음 히라가나 가타카나 쓰기노트', '해커스 일본어연구소', '7,200원')
# (536, '데일리 필로소피', '라이언 홀리데이', '16,200원')
# (537, '쾌적한 사회의 불쾌함', '구마시로 도루', '18,900원')
# (538, '2026 이유진 국어 백일기도 모의고사 [結(결) 적중]', '이유진', '30,600원')
# (539, '달러 자산 1억으로 평생 월급 완성하라 (2026 투자 전략 특별판)', '채부심(채상욱)', '18,900원')
# (540, '행복할 거야 이래도 되나 싶을 정도로', '일홍', '16,200원')
# (541, '기적의 초등 신문 2026', '강버들', '17,820원')
# (542, '2026 선재국어 출발선 봉투 모의고사', '이선재', '25,200원')
# (543, '부모는 가장 좋은 입시 멘토다', '박성오', '16,920원')
# (544, '1984', '조지 오웰', '9,900원')
# (545, '2026 유휘운 행정법총론 실전동형 모의고사', '유휘운', '9,900원')
# (546, '절대수익 우량주 매매법', '성경호', '35,100원')
# (547, '규칙파괴자', '데이비드 가드너', '22,500원')
# (548, '하루 한 장 나의 어휘력을 위한 필사 노트', '유선경', '21,420원')
# (549, '스킵과 로퍼 11 더블 특전판', '타카마츠 미사키', '5,400원')
# (550, 'ETS 토익기출 파트별 VOCA 보카', 'ETS', '11,700원')
# (551, '어른의 그릇', '조윤제', '17,100원')
# (552, '이방인', '알베르 까뮈', '9,000원')
# (553, '2026 이유진 국어 백일기도 모의고사 [承(승)_시간단축]', '이유진', '25,200원')
# (554, '정답은 있다', '이정효', '16,200원')
# (555, '뇌는 어떻게 나를 조종하는가', '크리스 나이바우어', '16,920원')
# (556, '새들이 전하는 짧은 철학', '필리프 J. 뒤부아', '15,300원')
# (557, '2026 이유진 국어 백일기도 모의고사 [轉(전) 극한훈련]', '이유진', '25,200원')
# (558, '눈과 돌멩이', '위수정', '16,200원')
# (559, '어머니의 집밥을 먹을 수 있는 횟수는 328번 남았습니다', '우와노 소라', '15,120원')
# (560, '반짝반짝 1학년, 학교는 널 기다려!', '전영신', '13,050원')
# (561, '손자병법', '손자', '11,700원')
# (562, '김재우의 기초 영어회화 100', '김재우', '17,010원')
# (563, '메이지의 영원한 삶을 위해', '크리스토퍼 엣지', '11,700원')
# (564, '존리의 부자되기 습관', '존리', '18,000원')
# (565, '해커스 토익 RC Reading(리딩) 기본서', 'David Cho', '16,920원')
# (566, '비실비실 선생님 11', '후쿠치 카미오', '5,400원')
# (567, '초판본 데미안', '헤르만 헤세', '1,980원')
# (568, 'AI 시대 십 대를 위한 논어', '최태규', '16,920원')
# (569, '총 균 쇠', '재레드 다이아몬드', '26,820원')
# (570, '두근두근 1학년, 우리는 널 사랑해!', '전영신', '13,050원')
# (571, '몬스터 캠핑장', '정주영', '12,600원')
# (572, '말뚝들', '김홍', '15,120원')
# (573, '어린이 같은 말 다른 뜻 사전', '박세랑', '16,020원')
# (574, '2026 위포트 공기업 NCS 통합기본서 (PSAT형+모듈형+피듈형+실전 모의고사)', '위포트 연구소', '24,300원')
# (575, '기분이 태도가 되지 않게 (헬로키티 에디션)', '레몬심리', '16,200원')
# (576, '불변의 법칙', '모건 하우절', '22,500원')
# (577, '나의 완벽한 장례식', '조현선', '17,100원')
# (578, '진보를 위한 주식투자', '이광수', '19,800원')
# (579, '박곰희 연금 부자 수업', '박곰희', '18,900원')
# (580, '괴테는 모든 것을 말했다', '스즈키 유이', '15,300원')
# (581, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 RC', 'ETS', '19,800원')
# (582, 'ETS 토익 정기시험 기출문제집 1000 Vol. 5 LC', 'ETS', '19,800원')
# (583, '죽은 왕녀를 위한 파반느 (양장 특별판)', '박민규', '18,000원')
# (584, '자몽살구클럽', '한로로', '10,800원')
# (585, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상', '최태성', '17,100원')
# (586, '너를 아끼며 살아라', '나태주', '16,650원')
# (587, '모순', '양귀자', '11,700원')
# (588, '돈의 방정식', '모건 하우절', '25,200원')
# (589, '자본주의 시대에서 살아남기 위한 최소한의 경제 공부', '백억남(김욱현)', '25,200원')
# (590, '1,000만 원으로 3년 안에 300만 원 월배당 만들기', '인생업(임승현)', '20,700원')
# (591, '위버멘쉬', '프리드리히 니체', '16,020원')
# (592, '엄마가 유령이 되었어!', '노부미', '10,800원')
# (593, '안녕이라 그랬어', '김애란', '15,120원')
# (594, '2026 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 하', '최태성', '16,650원')
# (595, '최소한의 삼국지', '최태성', '17,550원')
# (596, '싯다르타', '헤르만 헤세', '7,200원')
# (597, '2026 심우철 실전 동형 모의고사 Season 2', '심우철', '13,500원')
# (598, '사이토 히토리의 어떻게 살 것인가', '사이토 히토리', '11,700원')
# (599, '돈의 심리학 (50만 부 기념 뉴 에디션)', '모건 하우절', '22,320원')
# (600, '더블 클릭', '알간지', '17,100원')
# (601, '사카모토 데이즈 25 더블특전판', '스즈키 유우토', '5,850원')
# (602, '부처님 말씀대로 살아보니', '토니 페르난도', '17,010원')
# (603, '캔들차트 하나로 끝내는 추세추종 투자', '성승현', '22,500원')
# (604, '코스피 1만 넥스트 레벨', '박시동', '19,800원')
# (605, '혼모노', '성해나', '16,200원')
# (606, '해커스 토익 기출 VOCA (보카)', 'David Cho', '11,610원')
# (607, '나의 첫 월배당 ETF', '김정란', '19,800원')
# (608, '이해찬 회고록', '이해찬', '20,700원')
# (609, '설민석의 한국사 대모험 36', '설민석', '14,400원')
# (610, '코스모스', '칼 에드워드 세이건', '19,800원')
# (611, '향기로운 꽃은 늠름하게 핀다 18 더블특전판', '미카미 사카', '5,400원')
# (612, '운명을 보는 기술', '박성준', '16,920원')
# (613, '교사를 지키는 단단한 학급경영', '이종혁', '16,200원')
# (614, '어른의 행복은 조용하다', '태수', '16,020원')
# (615, '2026 써니 행정법총론 실전동형 모의고사', '박준철', '14,400원')
# (616, '2026 큰별쌤 최태성의 별별한국사 기출 500제 한국사능력검정시험 심화(1,2,3급)', '최태성', '19,800원')
# (617, '주식투자 무작정 따라하기', '윤재수', '22,500원')
# (618, '절창 切創', '구병모', '16,200원')
# (619, '아주 작은 습관의 힘 (50만 부 기념 스페셜 에디션)', '제임스 클리어', '16,200원')
# (620, '2026 문동균 한국사 국가직 대비 실전 봉투 모의고사', '문동균', '11,700원')
# (621, '2026 심우철 실전 동형 모의고사 Season 1', '심우철', '13,500원')
# (622, '내가 돈을 벌고 있다는 착각', 'commonD', '17,820원')
# (623, '최소한의 한국사', '최태성', '16,200원')
# (624, '내 심장을 쏴라', '정유정', '16,200원')
# (625, '2026 선재국어 결승선 봉투 모의고사', '이선재', '25,200원')
# (626, '2026 문동균 한국사 문단속 적중 최종병기 FINAL 모의고사', '문동균', '14,400원')
# (627, '내 친구는 왜 그럴까?', '최현주', '15,120원')
# (628, '급류', '정대건', '12,600원')
# (629, '김재우의 기본 동사 100', '김재우', '19,800원')
# (630, '다크 심리학', '다크 사이드 프로젝트', '19,710원')
# (631, '해커스 일본어 첫걸음 : 일본어 기초 20일 독학 완성!', '해커스 일본어연구소', '12,510원')
# (632, 'SQL 자격검정 실전문제', '한국데이터진흥원', '17,460원')
# (633, '렛뎀 이론', '멜 로빈스', '18,000원')
# (634, '니체의 초월자', '프리드리히 니체', '15,210원')
# (635, 'ETS 토익 단기공략 750+ (LC+RC)', 'ETS', '17,550원')
# (636, '프로젝트 헤일메리 (영화 특별판)', '앤디 위어', '19,800원')
# (637, '여덟 단어', '박웅현', '15,300원')
# (638, '데일 카네기 인간관계론 (50만부 돌파 초판 무삭제 완역본)', '데일 카네기', '10,350원')
# (639, '브람스를 좋아하세요...', '프랑수아즈 사강', '9,000원')
# (640, '긴긴밤', '루리', '11,250원')
# (641, '블루 아카이브 공식 4컷 청춘? 일상! 블루 아카이브 특별판', '돈미니', '47,700원')
# (642, '2026 문동균 한국사 D-30 문단속 모의고사', '문동균', '14,400원')
# (643, '인생을 위한 최소한의 생각', '신영준', '17,820원')
# (644, '오늘 밤, 세계에서 이 사랑이 사라진다 해도', '이치조 미사키', '12,600원')
# (645, '이게 되네? 제미나이 완전 미친 활용법 81제', '오힘찬', '21,600원')
# (646, '세이노의 가르침', '세이노(SayNo)', '6,480원')
# (647, '단다단 19', '타츠 유키노부', '5,400원')
# (648, '우리는 언제나 다시 만나', '윤여림', '10,800원')
# (649, '데미안', '헤르만 헤세', '7,200원')
# (650, '체인소 맨 22', '후지모토 타츠키', '5,400원')
# (651, '이기적 유전자 The Selfish Gene', '리처드 도킨스', '18,000원')
# (652, '2026 황철곤 행정학 실전동형 모의고사 SEASON 1', '황철곤', '14,400원')
# (653, '떠난 것은 돌아오지 않는다', '줄리언 반스', '16,200원')
# (654, '신뢰 게임', '현순엽', '22,000원')
# (655, '너를 미워할 시간에 나를 사랑하기로 했다', '윤서진', '16,920원')
# (656, '세종의 나라 1', '김진명', '19,800원')
# (657, '나쁜 일이 있어도 나쁜 날은 아니야', '정문정', '15,120원')
# (658, '부의 인문학 (20만부 기념 개정증보판)', '브라운스톤(우석)', '15,300원')
# (659, '인간 실격', '다자이 오사무', '8,100원')
# (660, '의사 어벤저스 25', '고희정', '14,220원')
# (661, 'Again! 뒤집어본 영문법', '오성호', '13,410원')
# (662, '할매', '황석영', '15,120원')
# (663, '원피스 ONE PIECE 113', '오다 에이이치로', '5,850원')
# (664, '돈의 속성 400쇄 리커버', '김승호', '16,020원')
# (665, '쇼펜하우어 인생수업 (30만 부 기념 개정증보판)', '쇼펜하우어', '15,750원')
# (666, '소년이 온다', '한강', '13,500원')
# (667, 'Go Go 카카오프렌즈 39 칠레', '김미영', '15,210원')
# (668, '나는 소망한다 내게 금지된 것을', '양귀자', '13,500원')
# (669, '2026 심승아 Simple·Detail 소방학개론 심봉사 심승아 봉투 모의고사', '심승아', '8,100원')
# (670, 'ETF 투자의 모든 것', '문일호', '18,900원')
# (671, '편안함의 습격', '마이클 이스터', '19,800원')
# (672, '일본 광고 카피 도감', '오하림', '16,920원')
# (673, '세종의 나라 2', '김진명', '19,800원')
# (674, '최상위권의 생기부', '정성민', '40,500원')
# (675, '어른의 품격을 채우는 100일 필사 노트', '김종원', '18,000원')
# (676, '흔한남매 21', '흔한남매', '15,120원')
# (677, '해커스 보카 Hackers Vocabulary', 'David Cho', '15,210원')
# (678, '은애하는 도적님아 대본집 세트', '이선', '47,700원')
# (679, '해커스 일본어 첫걸음 히라가나 가타카나 쓰기노트', '해커스 일본어연구소', '7,200원')
# (680, '데일리 필로소피', '라이언 홀리데이', '16,200원')
# (681, '쾌적한 사회의 불쾌함', '구마시로 도루', '18,900원')
# (682, '2026 이유진 국어 백일기도 모의고사 [結(결) 적중]', '이유진', '30,600원')
# (683, '달러 자산 1억으로 평생 월급 완성하라 (2026 투자 전략 특별판)', '채부심(채상욱)', '18,900원')
# (684, '행복할 거야 이래도 되나 싶을 정도로', '일홍', '16,200원')
# (685, '기적의 초등 신문 2026', '강버들', '17,820원')
# (686, '2026 선재국어 출발선 봉투 모의고사', '이선재', '25,200원')
# (687, '부모는 가장 좋은 입시 멘토다', '박성오', '16,920원')
# (688, '1984', '조지 오웰', '9,900원')
# (689, '2026 유휘운 행정법총론 실전동형 모의고사', '유휘운', '9,900원')
# (690, '절대수익 우량주 매매법', '성경호', '35,100원')
# (691, '규칙파괴자', '데이비드 가드너', '22,500원')
# (692, '하루 한 장 나의 어휘력을 위한 필사 노트', '유선경', '21,420원')
# (693, '스킵과 로퍼 11 더블 특전판', '타카마츠 미사키', '5,400원')
# (694, 'ETS 토익기출 파트별 VOCA 보카', 'ETS', '11,700원')
# (695, '어른의 그릇', '조윤제', '17,100원')
# (696, '이방인', '알베르 까뮈', '9,000원')
# (697, '2026 이유진 국어 백일기도 모의고사 [承(승)_시간단축]', '이유진', '25,200원')
# (698, '정답은 있다', '이정효', '16,200원')
# (699, '뇌는 어떻게 나를 조종하는가', '크리스 나이바우어', '16,920원')
# (700, '새들이 전하는 짧은 철학', '필리프 J. 뒤부아', '15,300원')
# (701, '2026 이유진 국어 백일기도 모의고사 [轉(전) 극한훈련]', '이유진', '25,200원')
# (702, '눈과 돌멩이', '위수정', '16,200원')
# (703, '어머니의 집밥을 먹을 수 있는 횟수는 328번 남았습니다', '우와노 소라', '15,120원')
# (704, '반짝반짝 1학년, 학교는 널 기다려!', '전영신', '13,050원')
# (705, '손자병법', '손자', '11,700원')
# (706, '김재우의 기초 영어회화 100', '김재우', '17,010원')
# (707, '메이지의 영원한 삶을 위해', '크리스토퍼 엣지', '11,700원')
# (708, '존리의 부자되기 습관', '존리', '18,000원')
# (709, '해커스 토익 RC Reading(리딩) 기본서', 'David Cho', '16,920원')
# (710, '비실비실 선생님 11', '후쿠치 카미오', '5,400원')
# (711, '초판본 데미안', '헤르만 헤세', '1,980원')
# (712, 'AI 시대 십 대를 위한 논어', '최태규', '16,920원')
# (713, '총 균 쇠', '재레드 다이아몬드', '26,820원')
# (714, '두근두근 1학년, 우리는 널 사랑해!', '전영신', '13,050원')
# (715, '몬스터 캠핑장', '정주영', '12,600원')
# (716, '말뚝들', '김홍', '15,120원')
# (717, '어린이 같은 말 다른 뜻 사전', '박세랑', '16,020원')
# (718, '2026 위포트 공기업 NCS 통합기본서 (PSAT형+모듈형+피듈형+실전 모의고사)', '위포트 연구소', '24,300원')
# (719, '기분이 태도가 되지 않게 (헬로키티 에디션)', '레몬심리', '16,200원')
# (720, '불변의 법칙', '모건 하우절', '22,500원')

# %% [markdown]
# # mysql에 저장하기

# %%
import pymysql
conn = pymysql.connect(
  host = 'localhost',
  user = 'root',
  password = '1234',
  db = 'book_db',
  charset = 'utf8mb4'
)
conn

# %%
with conn.cursor() as cursor:
  cursor.execute('''
  CREATE TABLE IF NOT EXISTS books (
      id INT AUTO_INCREMENT PRIMARY KEY,
      title VARCHAR(255),
      author VARCHAR(255),
      price VARCHAR(50)
)
''')

# %%
# insert data
with conn.cursor() as cursor:
  for book in books:
    cursor.execute('''
    INSERT INTO books (title, author, price) VALUES (%s, %s, %s)
    ''', (book.title, book.author, book.price))

conn.commit()
